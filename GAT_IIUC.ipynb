# %% [markdown]
# <a href="https://colab.research.google.com/github/Hasnainpriam/GAT_HAR/blob/main/GAT_IIUC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

path="/content/drive/MyDrive/thesis-data27.csv"

# %%
data=pd.read_csv(path)
data = data.drop('Unnamed: 0', axis=1)
data
# Out:
#            Acc_X     Acc_Y     Acc_Z  Class
# 0       2.660984 -9.653030  0.470237      1
# 1       2.223091  2.223091  2.223091      1
# 2       2.098372 -9.481953  0.926070      1
# 3       2.716461 -9.739352  0.912008      1
# 4       2.288388 -9.371498  0.910390      1
# ...          ...       ...       ...    ...
# 199802  8.533000 -2.310000 -5.367000     27
# 199803  8.402000 -2.192000 -4.447000     27
# 199804  8.661000 -2.593000 -4.205000     27
# 199805  7.818000 -3.499000 -4.045000     27
# 199806  6.572000 -3.087000 -3.598000     27
#
# [199807 rows x 4 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder,MinMaxScaler
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPool2D
from tensorflow.keras.optimizers import Adam

import seaborn as sns
from pylab import rcParams
from matplotlib import rc
from pandas.plotting import register_matplotlib_converters
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199807 entries, 0 to 199806
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Acc_X   199807 non-null  float64
#  1   Acc_Y   199807 non-null  float64
#  2   Acc_Z   199807 non-null  float64
#  3   Class   199807 non-null  int64
# dtypes: float64(3), int64(1)
# memory usage: 6.1 MB

# %%
#data = data[(data.Class != 5) & (data.Class != 6)]
#data

# %%
#path='/content/drive/MyDrive/Driving.csv'
#data_d=pd.read_csv(path)
#data_d=data_d.drop('Unnamed: 0', axis=1)

#data_d

# %%
#data_d.columns = ['Acc_X','Acc_Y','Acc_Z','Class']

# After renaming the columns
#print(data_d.columns)
#data_d

# %%
#data_d.info()

# %%
#frames = [data,data_d]

#result = pd.concat(frames, axis=0)

# %%
#result

# %%
#result.info()

# %%
#driving = result[(result.Class == 22) ]
#driving.drop(driving.columns[[0]], axis=1, inplace=True)
#driving

# %%
#driving.insert(0, 'Acc_X', driving.pop('Acc_X'))

#driving

# %%
#data=result

# %%
sns.countplot(x = 'Class',
              data = data,
              order = data.Class.value_counts().index);

# %%
sns.set(rc={'figure.figsize':(5,5)})
plt.xlabel('Axes')
plt.ylabel('Range')
fig= sns.boxplot(data=data.iloc[0:30000,0:3])
figure=fig.get_figure()

# %%
f=0
g=0
p=0


ind=data.index.to_series().groupby(data['Class']).agg(['first','last']).reset_index()
print(ind)
# Out:
#     Class   first    last
# 0       1       0    7399
# 1       2    7400   14800
# 2       3   14801   22201
# 3       4   22202   29602
# 4       5   29603   37003
# 5       6   37004   44404
# 6       7   44405   51805
# 7       8   51806   59206
# 8       9   59207   66606
# 9      10   66607   74006
# 10     11   74007   81406
# 11     12   81407   88806
# 12     13   88807   96206
# 13     14   96207  103606
# 14     15  103607  110006
# 15     16  110007  118406
# 16     17  118407  125806
# 17     18  125807  133206
# 18     19  133207  140606
# 19     20  140607  148006
# 20     21  148007  155406
# 21     22  155407  162806
# 22     23  162807  170206
# 23     24  170207  177606
# 24     25  177607  185006
# 25     26  185007  197606
# 26     27  192407  199806

# %%
for m in range(1,28):
    A = data.loc[data['Class'] == m]
    print(A.shape)
    first=ind.iloc[p,1]
    print(first)
    last=ind.iloc[p,2]
    print(last)
    for i in range(0,2):
        Avg= np.mean(A.iloc[:,i])
        #Avg
        Q1 = A.iloc[:,i].quantile(0.25)
        #Q1
        Q3 = A.iloc[:,i].quantile(0.75)
        #Q3
        IQR = Q3 - Q1
        #IQR
        lim1=(Q1 - 1.5 * IQR)
        #lim1
        lim2=(Q3 + 1.5 * IQR)
        #lim2
        for ami in range(first,last+1):
            com=data.iloc[ami,i]
            if ((com < lim1) |(com > lim2)):
                data.iloc[ami,i] = Avg
                f=f+1
        print(f)
    if(p<27):
        p=p+1
# Out:
# (7400, 4)
# 0
# 7399
# 0
# 83
# (7401, 4)
# 7400
# 14800
# 83
# 118
# (7401, 4)
# 14801
# 22201
# 118
# 320
# (7401, 4)
# 22202
# 29602
# 576
# 1528
# (7401, 4)
# 29603
# 37003
# 1528
# 1528
# (7401, 4)
# 37004
# 44404
# 1528
# 1528
# (7401, 4)
# 44405
# 51805
# 1528
# 1528
# (7401, 4)
# 51806
# 59206
# 2357
# 2380
# (7400, 4)
# 59207
# 66606
# 2689
# 2753
# (7400, 4)
# 66607
# 74006
# 2871
# 2871
# (7400, 4)
# 74007
# 81406
# 2871
# 3180
# (7400, 4)
# 81407
# 88806
# 3313
# 3458
# (7400, 4)
# 88807
# 96206
# 3897
# 3897
# (7400, 4)
# 96207
# 103606
# 3897
# 3946
# (6400, 4)
# 103607
# 110006
# 5431
# 5431
# (8400, 4)
# 110007
# 118406
# 5431
# 5431
# (7400, 4)
# 118407
# 125806
# 6579
# 6579
# (7400, 4)
# 125807
# 133206
# 6585
# 6585
# (7400, 4)
# 133207
# 140606
# 6585
# 6585
# (7400, 4)
# 140607
# 148006
# 6714
# 6792
# (7400, 4)
# 148007
# 155406
# 6792
# 6792
# (7400, 4)
# 155407
# 162806
# 7263
# 7852
# (7400, 4)
# 162807
# 170206
# 9105
# 9608
# (7400, 4)
# 170207
# 177606
# 9616
# 9653
# (7400, 4)
# 177607
# 185006
# 9653
# 10186
# (10200, 4)
# 185007
# 197606
# 10793
# 10793
# (4600, 4)
# 192407
# 199806
# 10870
# 10903

# %%
sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(5,5)})
plt.xlabel('Axes')
plt.ylabel('Range')
fig=sns.boxplot(data=data.iloc[0:8000,0:3],whis=[0, 100])
count=0
figure=fig.get_figure()

# %%
data.to_csv('withoutoutlier.csv')

# %%
balanced_data = pd.read_csv('withoutoutlier.csv')
balanced_data
# Out:
#         Unnamed: 0     Acc_X     Acc_Y     Acc_Z  Class
# 0                0  2.660984 -9.653030  0.470237      1
# 1                1  2.223091 -9.432167  2.223091      1
# 2                2  2.098372 -9.481953  0.926070      1
# 3                3  2.716461 -9.739352  0.912008      1
# 4                4  2.288388 -9.371498  0.910390      1
# ...            ...       ...       ...       ...    ...
# 199802      199802  8.533000 -2.310000 -5.367000     27
# 199803      199803  8.402000 -2.192000 -4.447000     27
# 199804      199804  8.661000 -2.593000 -4.205000     27
# 199805      199805  7.818000 -3.499000 -4.045000     27
# 199806      199806  6.572000 -3.087000 -3.598000     27
#
# [199807 rows x 5 columns]

# %%
balanced_data = balanced_data[(balanced_data.Class != 5) & (balanced_data.Class != 6) & (balanced_data.Class != 15)& (balanced_data.Class != 24)]
balanced_data
# Out:
#         Unnamed: 0     Acc_X     Acc_Y     Acc_Z  Class
# 0                0  2.660984 -9.653030  0.470237      1
# 1                1  2.223091 -9.432167  2.223091      1
# 2                2  2.098372 -9.481953  0.926070      1
# 3                3  2.716461 -9.739352  0.912008      1
# 4                4  2.288388 -9.371498  0.910390      1
# ...            ...       ...       ...       ...    ...
# 199802      199802  8.533000 -2.310000 -5.367000     27
# 199803      199803  8.402000 -2.192000 -4.447000     27
# 199804      199804  8.661000 -2.593000 -4.205000     27
# 199805      199805  7.818000 -3.499000 -4.045000     27
# 199806      199806  6.572000 -3.087000 -3.598000     27
#
# [171205 rows x 5 columns]

# %%
label = LabelEncoder()
balanced_data['label'] = label.fit_transform(balanced_data['Class'])
balanced_data
# Out:
# <ipython-input-24-4c87dd121a69>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   balanced_data['label'] = label.fit_transform(balanced_data['Class'])
#         Unnamed: 0     Acc_X     Acc_Y     Acc_Z  Class  label
# 0                0  2.660984 -9.653030  0.470237      1      0
# 1                1  2.223091 -9.432167  2.223091      1      0
# 2                2  2.098372 -9.481953  0.926070      1      0
# 3                3  2.716461 -9.739352  0.912008      1      0
# 4                4  2.288388 -9.371498  0.910390      1      0
# ...            ...       ...       ...       ...    ...    ...
# 199802      199802  8.533000 -2.310000 -5.367000     27     22
# 199803      199803  8.402000 -2.192000 -4.447000     27     22
# 199804      199804  8.661000 -2.593000 -4.205000     27     22
# 199805      199805  7.818000 -3.499000 -4.045000     27     22
# 199806      199806  6.572000 -3.087000 -3.598000     27     22
#
# [171205 rows x 6 columns]

# %%
dfn = balanced_data.drop('Unnamed: 0', axis=1)
dfn
# Out:
#            Acc_X     Acc_Y     Acc_Z  Class  label
# 0       2.660984 -9.653030  0.470237      1      0
# 1       2.223091 -9.432167  2.223091      1      0
# 2       2.098372 -9.481953  0.926070      1      0
# 3       2.716461 -9.739352  0.912008      1      0
# 4       2.288388 -9.371498  0.910390      1      0
# ...          ...       ...       ...    ...    ...
# 199802  8.533000 -2.310000 -5.367000     27     22
# 199803  8.402000 -2.192000 -4.447000     27     22
# 199804  8.661000 -2.593000 -4.205000     27     22
# 199805  7.818000 -3.499000 -4.045000     27     22
# 199806  6.572000 -3.087000 -3.598000     27     22
#
# [171205 rows x 5 columns]

# %%
plt.figure(figsize=(8,5))

plt.plot(dfn.iloc[:, 0:3])
# Out:
# [<matplotlib.lines.Line2D at 0x78b870386bf0>,
#  <matplotlib.lines.Line2D at 0x78b870386c50>,
#  <matplotlib.lines.Line2D at 0x78b870386c80>]

# %%
X = dfn[['Acc_X', 'Acc_Y', 'Acc_Z']]
y = dfn['label']

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

X
# Out:
# array([[ 0.85781211, -0.94173197, -0.56621771],
#        [ 0.74856246, -0.90332142, -0.16647194],
#        [ 0.71744639, -0.91197982, -0.46226307],
#        ...,
#        [ 2.35475232,  0.28608406, -1.63242531],
#        [ 2.14443278,  0.1285208 , -1.59593664],
#        [ 1.83356902,  0.20017208, -1.49399639]])

# %%
#my_array = np.array(X)

#df = pd.DataFrame(my_array, columns = ['Acc_X',	'Acc_Y','Acc_Z'])

#print(df)
#print(type(df))

# %%
scaled_X = pd.DataFrame(data = X, columns = ['Acc_X', 'Acc_Y', 'Acc_Z'])

plt.figure(figsize=(8,5))

plt.plot(scaled_X .iloc[:, 0:3])
# Out:
# [<matplotlib.lines.Line2D at 0x78b8703e7940>,
#  <matplotlib.lines.Line2D at 0x78b8703e79a0>,
#  <matplotlib.lines.Line2D at 0x78b8703e79d0>]

# %%
scaled_X['mag'] = np.sqrt(scaled_X['Acc_X'] ** 2 + scaled_X['Acc_Y'] ** 2 + scaled_X['Acc_Z'] ** 2)
scaled_X['label'] = y.values

scaled_X.head()
# Out:
#       Acc_X     Acc_Y     Acc_Z       mag  label
# 0  0.857812 -0.941732 -0.566218  1.394024      0
# 1  0.748562 -0.903321 -0.166472  1.184925      0
# 2  0.717446 -0.911980 -0.462263  1.249049      0
# 3  0.871653 -0.956744 -0.465470  1.375428      0
# 4  0.764853 -0.892770 -0.465839  1.264534      0

# %%
scaled_X = scaled_X.drop(['Acc_X', 'Acc_Y', 'Acc_Z'], axis=1)

scaled_X
# Out:
#              mag  label
# 0       1.394024      0
# 1       1.184925      0
# 2       1.249049      0
# 3       1.375428      0
# 4       1.264534      0
# ...          ...    ...
# 171200  3.017967     22
# 171201  2.866944     22
# 171202  2.879499     22
# 171203  2.676214     22
# 171204  2.373619     22
#
# [171205 rows x 2 columns]

# %%
import scipy.stats as stats

# %%
Fs = 20
frame_size = Fs * 20
hop_size = Fs * 1
frames = []
labels = []

for i in range(0, len(scaled_X) - frame_size, hop_size):
    x = scaled_X['mag'].values[i: i + frame_size]
    label = stats.mode(scaled_X['label'][i: i + frame_size])[0][0]
    frames.append([x])
    labels.append(label)
# Out:
# <ipython-input-34-d5294cde681b>:9: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   label = stats.mode(scaled_X['label'][i: i + frame_size])[0][0]

# %%
len(frames) , len(labels)
# Out:
# (8541, 8541)

# %%
frames = np.asarray(frames).reshape(-1, frame_size)
labels = np.asarray(labels)

# %%
print("RESHAPE SHAPE: ",frames.shape)
print("LABELS: ",labels.shape)
# Out:
# RESHAPE SHAPE:  (8541, 400)
# LABELS:  (8541,)

# %%
x=frames
y=labels

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=123, stratify=y)

# %%
training_files=[x_train, y_train]
subject_files=[x_test, y_test]

# %%
class ProgressMeter(object):
    def __init__(self, num_batches, *meters, prefix=""):
        self.batch_fmtstr = self._get_batch_fmtstr(num_batches)
        self.meters = meters
        self.prefix = prefix

    def print(self, batch):
        entries = [self.prefix + self.batch_fmtstr.format(batch)]
        entries += [str(meter) for meter in self.meters]
        print('\t'.join(entries))

    def _get_batch_fmtstr(self, num_batches):
        num_digits = len(str(num_batches // 1))
        fmt = '{:' + str(num_digits) + 'd}'
        return '[' + fmt + '/' + fmt.format(num_batches) + ']'

# %%
import torch
from torch.utils.data import Dataset


class LoadDataset_from_numpy(Dataset):
    def __init__(self, np_data):
        super(LoadDataset_from_numpy, self).__init__()
        X_train = np_data[0]
        y_train = np_data[1]
        self.len = X_train.shape[0]
        self.x_data = torch.from_numpy(X_train).float()
        self.y_data = torch.from_numpy(y_train).long()
        self.x_data = self.x_data.view(self.x_data.size()[0], 1, self.x_data.size()[1])

    def __getitem__(self, index):
        return self.x_data[index], self.y_data[index]

    def __len__(self):
        return self.len


def data_generator_np(training_files, subject_files, batch_size):
    train_dataset = LoadDataset_from_numpy(training_files)
    test_dataset = LoadDataset_from_numpy(subject_files)

    train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                               batch_size=batch_size,
                                               shuffle=True,
                                               drop_last=True,
                                               num_workers=0)

    test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                              batch_size=batch_size,
                                              shuffle=False,
                                              drop_last=True,
                                              num_workers=0)

    return train_loader, test_loader

# %%
train_loader, test_loader = data_generator_np(training_files, subject_files, 64)
#batch_size=64

# %%
import torch.nn as nn
from torch.nn import functional as f



class SignalSegmentDefinition(nn.Module):

    def __init__(self, kernel_size, stride):
        super().__init__()
        self.kernel_size = kernel_size
        self.stride = stride

    def forward(self, x):
        b = f.unfold(x, kernel_size=self.kernel_size, stride=self.stride)  # overlapping sliding window
        b = b.permute(0, 2, 1)
        b = b.unsqueeze(-2)
        return b


class SignalSegmentRepresentation(nn.Module):

    def __init__(self, segment_size, overlapping_rate, segment_num):
        super(SignalSegmentRepresentation, self).__init__()
        self.overlapping = int(segment_size - segment_size * overlapping_rate)
        self.segment = SignalSegmentDefinition((1, segment_size), self.overlapping)
        self.segment2vec = SignalSegment2Vec(30)
        self.gna = GNA(segment_num)

    def forward(self, x):
        signal_segments = []
        x = self.segment(x)
        x = x.squeeze()
        "share the SignalSegment2Vec Encoder"
        for idx in range(x.size()[1]):
            data = x[:, idx, :]
            data = data.unsqueeze(1)
            out = self.segment2vec(data)
            out = out.view(x.size()[0], 1, -1)
            signal_segments.append(out)
        signal_segments = torch.cat(signal_segments, dim=1)
        signal_segments = signal_segments .unsqueeze(2)
        "global node attention"
        signal_segments = self.gna(signal_segments).permute(0, 2, 1, 3)
        return signal_segments


class GNA(nn.Module):

    def __init__(self, channel, reduction=2):
        super(GNA, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Conv2d(channel, channel // reduction, 1, bias=False),
            nn.GELU(),
            nn.Conv2d(channel // reduction, channel, 1, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x)
        y = self.fc(y)
        return x * y.expand_as(x)


class SignalSegment2Vec(nn.Module):

    def __init__(self, afr_reduced_cnn_size):
        super(SignalSegment2Vec, self).__init__()
        self.features = nn.Sequential(
            nn.Conv1d(1, 64, kernel_size=49, stride=6, bias=False, padding=int(49//2)),
            nn.BatchNorm1d(64),
            nn.GELU(),
            nn.MaxPool1d(kernel_size=7, stride=4, padding=int(7//2)),

            nn.Conv1d(64, 128, kernel_size=7, stride=1, bias=False, padding=int(7//2)),
            nn.BatchNorm1d(128),
            nn.GELU(),

            nn.Conv1d(128, 128, kernel_size=7, stride=1, bias=False, padding=int(7//2)),
            nn.BatchNorm1d(128),
            nn.GELU(),

            nn.MaxPool1d(kernel_size=3, stride=4, padding=int(3//2)),
        )

        self.inplanes = 128
        self.AFR = self._make_layer(ResBasicBlock, afr_reduced_cnn_size, 1)

    def _make_layer(self, block, planes, blocks, stride=1):
        downsample = None
        if stride != 1 or self.inplanes != planes * block.expansion:
            downsample = nn.Sequential(
                nn.Conv1d(self.inplanes, planes * block.expansion,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm1d(planes * block.expansion),
            )
        layers = []
        layers.append(block(self.inplanes, planes, stride, downsample))
        self.inplanes = planes * block.expansion
        for i in range(1, blocks):
            layers.append(block(self.inplanes, planes))
        return nn.Sequential(*layers)

    def forward(self, x):
        x = self.features(x)
        x = self.AFR(x)
        return x



class ResLayer(nn.Module):
    def __init__(self, channel, reduction=2):
        super(ResLayer, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.GELU(),
            nn.Linear(channel // reduction, channel, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1)
        return x * y.expand_as(x)


class ResBasicBlock(nn.Module):
    expansion = 1

    def __init__(self, inplanes, planes, stride=1, downsample=None, reduction=4):
        super(ResBasicBlock, self).__init__()
        self.conv1 = nn.Conv1d(inplanes, planes, stride)
        self.bn1 = nn.BatchNorm1d(planes)
        self.relu = nn.GELU()
        self.conv2 = nn.Conv1d(planes, planes, 1)
        self.bn2 = nn.BatchNorm1d(planes)
        self.reslayer = ResLayer(planes, reduction)
        self.downsample = downsample
        self.stride = stride

    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out = self.reslayer(out)
        if self.downsample is not None:
            residual = self.downsample(x)
        out += residual
        out = self.relu(out)
        return out

# %%
class Attention(nn.Module):

    def __init__(self, channel, reduction=2):
        super().__init__()
        self.attn = nn.Sequential(
            nn.AdaptiveAvgPool2d((None, 1)),
            nn.Conv2d(channel, channel // reduction, 1, bias=False),
            nn.GELU(),
            nn.Conv2d(channel // reduction, channel, 1, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        B, M, K, _ = x.size()
        adj = self.pearson(x)  # adjacency matrix
        x_ = self._prepare_attentional_mechanism_input(x)
        e = self.attn(x_)
        e = e.permute(0, 2, 1, 3).contiguous()
        e = e.view(B, M, K, K)
        zero_vec_adj = -9e15 * torch.ones_like(adj)
        attention = torch.where(adj > 0, e, zero_vec_adj)
        attention = f.softmax(attention, dim=-1)
        x = torch.matmul(attention, x)
        return x, adj

    def h_matmul(self, x):
        N = x.size()[-2]
        x_repeated_in_chunks = x.repeat_interleave(N, dim=-2)
        x_repeated_alternating = x.repeat(1, 1, N, 1)
        result = torch.mul(x_repeated_in_chunks, x_repeated_alternating)
        return result

    def pearson(self, x):
        centered_h = x - x.mean(dim=-1, keepdim=True)
        covariance = self.h_matmul(centered_h).sum(dim=-1, keepdim=True)
        bessel_corrected_covariance = torch.div(covariance, (x.shape[-1] - 1))
        std_h = x.std(dim=-1, keepdim=True)
        p = torch.div(bessel_corrected_covariance, (self.h_matmul(std_h)))
        p = p.view(x.size()[0], x.size()[1], x.size()[2], -1)
        return p

    def _prepare_attentional_mechanism_input(self, x):
        B, _, K, _ = x.size()
        x_repeated_in_chunks = x.repeat_interleave(K, dim=-2)
        x_repeated_alternating = x.repeat(1, 1, K, 1)

        pos = 2 * torch.ones_like(x_repeated_alternating)
        one_vec = torch.ones_like(x_repeated_alternating)
        x_repeated_in_chunks.eq(x_repeated_alternating)
        pos = torch.where(x_repeated_in_chunks.eq(x_repeated_alternating) > 0, one_vec, pos)
        x_repeated_alternating = pos * x_repeated_alternating

        all_combinations_matrix = torch.cat([x_repeated_in_chunks, x_repeated_alternating], dim=-1)
        all_combinations_matrix = all_combinations_matrix.permute(0, 2, 1, 3)
        return all_combinations_matrix


class Block(nn.Module):

    def __init__(self, node_size, input_size, kernel_size, stride, multi_heads):
        super().__init__()

        expand = 1

        padding = kernel_size//2
        self.mid_channels_ = (multi_heads - kernel_size + 2 * padding) // stride + 1

        self.multi_head = nn.Sequential(
            nn.Conv2d(input_size, multi_heads, 1, bias=False),
            nn.Conv2d(multi_heads, multi_heads, 1, bias=False)
        )

        self.feature_extraction = nn.Sequential(
            nn.Conv2d(node_size, node_size, kernel_size=kernel_size, stride=stride, padding=padding,
                      groups=node_size, bias=False),
            nn.BatchNorm2d(node_size),
            nn.GELU()
        )

        self.attn = Attention(node_size * node_size)

        self.feed_forward = nn.Sequential(
            nn.Conv2d(self.mid_channels_, self.mid_channels_ * 4, 1, bias=False),
            nn.BatchNorm2d(self.mid_channels_ * 4),
            nn.GELU(),
            nn.Conv2d(self.mid_channels_ * 4, multi_heads * expand, 1, bias=False),
            nn.BatchNorm2d(multi_heads)
        )

        self.shortcut = nn.Sequential(
            nn.Conv2d(node_size, node_size, kernel_size=kernel_size, stride=stride, padding=padding, bias=False),
            nn.BatchNorm2d(node_size),
            nn.AdaptiveAvgPool2d((1, None))
        )

        self.norm = nn.BatchNorm2d(multi_heads)

    def forward(self, x):
        res = x.permute(0, 2, 1, 3)                 # B, J, K, C -> B, K, J, C
        "Dense layers"
        out = self.multi_head(x)                    # B, J, K, C -> B, M, K, C, where M is the number of heads
        out, adj = self.attn(out)
        self.adj = adj                              # for visualization
        out = f.gelu(self.norm(out))
        out = out.permute(0, 2, 1, 3)               # B, M, K, C -> B, K, M, C
        "Attention Layers"
        out = self.feature_extraction(out)          # B, K, M, C -> B, K, M', C'
        out = out.permute(0, 2, 1, 3)               # B, K, M', C' -> B, M', K, C'
        out = self.feed_forward(out)                # B, M', K, C' -> B, M'', K, C''
        shortcut = self.shortcut(res)               # B, K, J, C -> B, 1, K, C''
        shortcut = shortcut.permute(0, 2, 1, 3)
        out += shortcut                             # (B, M'', K, C'') + (B, 1, K, C'') -> (B, M'', K, C'') Broadcast
        return out

# %%
import torch.nn.functional as F

# %%
class GRAPHSENSOR(nn.Module):

    def __init__(self, segment_size, overlapping_rate, in_channels, class_num):
        super(GRAPHSENSOR, self).__init__()
        self.segment_size = segment_size
        self.signal_segments = SignalSegmentRepresentation(segment_size, overlapping_rate, in_channels)

        self.attn = nn.Sequential(
            Block(in_channels, 1,   5, 2, 16),
            Block(in_channels, 16,  5, 2, 32),
            Block(in_channels, 32,  5, 1, 64),
            Block(in_channels, 64,  5, 1, 128),
        )

        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels * 128, 512, 1, bias=False),
            nn.BatchNorm2d(512),
            nn.GELU()
        )
        self.avgpool = nn.AdaptiveAvgPool2d((None, 1))
        self.conv3 = nn.Sequential(
            nn.Conv2d(512, 1024, 1, bias=False),
            nn.BatchNorm2d(1024),
            nn.GELU()
        )
        self.conv4 = nn.Conv2d(1024, class_num, 1, bias=False)

    def forward(self, x):
        x = x.unsqueeze(1)
        x = self.signal_segments(x)
        x = self.attn(x)
        x = self.avgpool(x)
        x = x.flatten(1).unsqueeze(-1).unsqueeze(-1)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = x.flatten(1)
        return F.log_softmax(x, dim=-1)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %%
model = GRAPHSENSOR(segment_size=80, overlapping_rate=0.5, in_channels=9, class_num=23).to(device)

# %%
def count_parameters(model):
        return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameter')
# Out:
# The model has 1,563,816 trainable parameter

# %%
if torch.cuda.device_count() >= 1:
        print("num GPUs: ", torch.cuda.device_count())
        model = nn.DataParallel(model).to(device)
# Out:
# num GPUs:  1

# %%
best_acc = 0
best_f1 = 0

# %%
import os
import argparse
import time
import random
import torch.optim as optim

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=0.001, amsgrad=True)
criterion = nn.CrossEntropyLoss().to(device)

# %%
start_time = time.time()

# %%
def adjust_learning_rate(optimizer, epoch, args):
    if epoch == 20:
        for param_group in optimizer.param_groups:
            param_group['lr'] = 0.0001

# %%
class AverageMeter(object):
    def __init__(self, name, fmt=':f'):
        self.name = name
        self.fmt = fmt
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

    def __str__(self):
        fmtstr = '{name} {val' + self.fmt + '} ({avg' + self.fmt + '})'
        return fmtstr.format(**self.__dict__)

# %%
def accuracy_(output, target):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)
        assert pred.shape[0] == len(target)
        correct = 0
        correct += torch.sum(pred == target).item()
        return correct * 100 / len(target)


def f1_(output, target):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)
        assert pred.shape[0] == len(target)
    return f1_score(pred.cpu().numpy(), target.data.cpu().numpy(), average='macro')

# %%
test_accuracies = []
test_f1_scores = []
test_losses=[]

# %%
train_accuracies = []
train_f1_scores = []
train_losses=[]

epoch_train_accuracies = []
epoch_train_f1_scores = []
epoch_train_losses=[]

# %%
def train(train_loader, model, criterion, optimizer, epoch, print_interval):
    batch_time = AverageMeter('Time', ':6.3f')
    data_time = AverageMeter('Data', ':6.3f')
    losses = AverageMeter('Loss', ':.4e')
    accuracy = AverageMeter('accuracy', ':.4e')
    f1_score = AverageMeter('f1_score', ':.4e')

    # switch to train mode
    model.train()

    end = time.time()
    for i, (data, target) in enumerate(train_loader):
        # measure data loading time
        data_time.update(time.time() - end)
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        losses.update(loss.item(), data.size(0))
        acc = accuracy_(output, target)
        f1 = f1_(output, target) * 100
        accuracy.update(acc, data.size(0))
        f1_score.update(f1, data.size(0))

        loss.backward()
        optimizer.step()

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if i % print_interval == 0:
            print('Epoch: [{0}][{1}/{2}]\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                  'accuracy {accuracy.val:.3f} ({accuracy.avg:.3f})\t'
                  'f1_score {f1_score.val:.3f} ({f1_score.avg:.3f})'.format(
                epoch, i, len(train_loader), loss=losses, accuracy=accuracy, f1_score=f1_score))

        epoch_train_accuracies.append(accuracy.avg)
        epoch_train_f1_scores.append(f1_score.avg )
        epoch_train_losses.append(losses.avg )

    train_accuracies.append(sum(epoch_train_accuracies)/len(epoch_train_accuracies))
    train_f1_scores.append(sum(epoch_train_f1_scores)/len(epoch_train_f1_scores) )
    train_losses.append(sum(epoch_train_losses)/len(epoch_train_losses) )

    print(" Train: accuracy", train_accuracies[-1]," loss" ,train_losses[-1]," f1 score:", train_f1_scores[-1])

    epoch_train_accuracies.clear()
    epoch_train_f1_scores.clear()
    epoch_train_losses.clear()

# %%
def validate(val_loader, model, criterion, args):
    batch_time = AverageMeter('Time', ':6.3f')
    losses = AverageMeter('Loss', ':.4e')
    accuracy = AverageMeter('accuracy', ':.4e')
    f1_score = AverageMeter('f1_score ', ':.4e')
    progress = ProgressMeter(len(val_loader), losses, accuracy, f1_score,
                             prefix='Test: ')

    # switch to evaluate mode
    model.eval()
    with torch.no_grad():
        end = time.time()
        for i, (data, target) in enumerate(val_loader):
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss = criterion(output, target)

            losses.update(loss.item(), data.size(0))
            acc = accuracy_(output, target)
            f1 = f1_(output, target) * 100
            accuracy.update(acc, data.size(0))
            f1_score.update(f1, data.size(0))

            # measure elapsed time
            batch_time.update(time.time() - end)
            end = time.time()



            # TODO: this should also be done with the ProgressMeter
        print(' Test: accuracy {accuracy.avg:.3f} loss {loss.avg:.4f} f1_score {f1_score.avg:.3f} '
              .format(accuracy=accuracy,loss=losses, f1_score=f1_score))

        test_accuracies.append(accuracy.avg)
        test_f1_scores.append(f1_score.avg )
        test_losses.append(losses.avg )

        return accuracy.avg, f1_score.avg

# %%
epochs=300

# %%
for epoch in range(epochs):
    print("\nStart of epoch NO: %d" % (epoch,))
    adjust_learning_rate(optimizer, epoch, args=1)
    train(train_loader, model, criterion,  optimizer, epoch, print_interval=40)
    acc, f1 = validate(test_loader, model, criterion,  args=1)

    is_best = acc > best_acc
    best_acc = max(acc, best_acc)

    if is_best:
            print('Saving..')
            best_f1 = f1
            state = {
                'model': model.state_dict(),
                'best_acc1': best_acc,
                'best_acc5': best_f1,
                'epoch': epoch,
            }
            if not os.path.isdir('checkpoint'):
                os.mkdir('checkpoint')
            filename = "best_model"
            torch.save(state, './checkpoint/' + filename + '_ckpt.t7')

    time_interval = time.time() - start_time
    time_split = time.gmtime(time_interval)
    print("Model Training time: ", time_interval, "Hour: ", time_split.tm_hour, "Minute: ", time_split.tm_min, "Second: ",
              time_split.tm_sec, end='')
    print("\n Test best accuracy:", best_acc, " Test best f1 score:", best_f1)
# Out:
# Start of epoch NO: 0
# Epoch: [0][0/106]	Loss 3.1931 (3.1931)	accuracy 7.812 (7.812)	f1_score 2.464 (2.464)
# Epoch: [0][40/106]	Loss 1.5137 (1.9830)	accuracy 45.312 (31.898)	f1_score 39.033 (23.477)
# Epoch: [0][80/106]	Loss 1.3695 (1.7320)	accuracy 46.875 (37.982)	f1_score 42.486 (29.146)
#  Train: accuracy 31.08038728732473  loss 2.016899868899797  f1 score: 22.808772280223597
#  Test: accuracy 46.875 loss 1.4475 f1_score 37.986
# Saving..
# Model Training time:  16.947299480438232 Hour:  0 Minute:  0 Second:  16
#  Test best accuracy: 46.875  Test best f1 score: 37.9857007338572
#
# Start of epoch NO: 1
# Epoch: [1][0/106]	Loss 1.4783 (1.4783)	accuracy 45.312 (45.312)	f1_score 38.838 (38.838)
# Epoch: [1][40/106]	Loss 1.8512 (1.3003)	accuracy 32.812 (50.114)	f1_score 32.511 (42.418)
# Epoch: [1][80/106]	Loss 1.0745 (1.2478)	accuracy 64.062 (51.640)	f1_score 59.278 (43.968)
#  Train: accuracy 49.96800617740804  loss 1.3041435200799447  f1 score: 42.66598994870941
#  Test: accuracy 55.228 loss 1.1016 f1_score 45.637
# Saving..
# Model Training time:  24.02505135536194 Hour:  0 Minute:  0 Second:  24
#  Test best accuracy: 55.22836538461539  Test best f1 score: 45.636558175357095
#
# Start of epoch NO: 2
# Epoch: [2][0/106]	Loss 1.0477 (1.0477)	accuracy 60.938 (60.938)	f1_score 46.035 (46.035)
# Epoch: [2][40/106]	Loss 0.8802 (1.0757)	accuracy 62.500 (58.155)	f1_score 51.403 (51.344)
# Epoch: [2][80/106]	Loss 1.3583 (1.0736)	accuracy 51.562 (58.044)	f1_score 39.869 (50.677)
#  Train: accuracy 58.68492999672008  loss 1.069694366574453  f1 score: 50.93092490711387
#  Test: accuracy 48.377 loss 1.6336 f1_score 43.519
# Model Training time:  31.919368743896484 Hour:  0 Minute:  0 Second:  31
#  Test best accuracy: 55.22836538461539  Test best f1 score: 45.636558175357095
#
# Start of epoch NO: 3
# Epoch: [3][0/106]	Loss 0.8609 (0.8609)	accuracy 64.062 (64.062)	f1_score 58.770 (58.770)
# Epoch: [3][40/106]	Loss 0.8065 (1.0322)	accuracy 73.438 (58.803)	f1_score 71.421 (50.577)
# Epoch: [3][80/106]	Loss 0.9393 (1.0134)	accuracy 57.812 (59.915)	f1_score 54.099 (52.180)
#  Train: accuracy 59.6345901397967  loss 1.0152898495871976  f1 score: 51.52280567533948
#  Test: accuracy 29.928 loss 3.3339 f1_score 20.376
# Model Training time:  39.01893949508667 Hour:  0 Minute:  0 Second:  39
#  Test best accuracy: 55.22836538461539  Test best f1 score: 45.636558175357095
#
# Start of epoch NO: 4
# Epoch: [4][0/106]	Loss 1.4028 (1.4028)	accuracy 54.688 (54.688)	f1_score 42.060 (42.060)
# Epoch: [4][40/106]	Loss 1.0049 (0.9984)	accuracy 67.188 (61.052)	f1_score 50.226 (53.263)
# Epoch: [4][80/106]	Loss 1.0105 (0.9782)	accuracy 62.500 (61.709)	f1_score 57.627 (53.781)
#  Train: accuracy 60.460928633546175  loss 1.0121382766160099  f1 score: 52.44805710650582
#  Test: accuracy 43.810 loss 1.8640 f1_score 34.434
# Model Training time:  46.9438533782959 Hour:  0 Minute:  0 Second:  46
#  Test best accuracy: 55.22836538461539  Test best f1 score: 45.636558175357095
#
# Start of epoch NO: 5
# Epoch: [5][0/106]	Loss 0.8953 (0.8953)	accuracy 59.375 (59.375)	f1_score 53.875 (53.875)
# Epoch: [5][40/106]	Loss 0.8175 (0.8757)	accuracy 62.500 (66.159)	f1_score 53.099 (59.293)
# Epoch: [5][80/106]	Loss 0.9219 (0.8667)	accuracy 56.250 (65.664)	f1_score 46.582 (58.645)
#  Train: accuracy 66.01206360670918  loss 0.8796015009066348  f1 score: 59.16221933422252
#  Test: accuracy 51.142 loss 1.3654 f1_score 43.372
# Model Training time:  56.472235679626465 Hour:  0 Minute:  0 Second:  56
#  Test best accuracy: 55.22836538461539  Test best f1 score: 45.636558175357095
#
# Start of epoch NO: 6
# Epoch: [6][0/106]	Loss 0.7962 (0.7962)	accuracy 67.188 (67.188)	f1_score 63.986 (63.986)
# Epoch: [6][40/106]	Loss 0.7752 (0.8682)	accuracy 60.938 (65.282)	f1_score 52.311 (59.593)
# Epoch: [6][80/106]	Loss 0.7388 (0.8367)	accuracy 67.188 (66.127)	f1_score 62.340 (59.966)
#  Train: accuracy 65.56918693703246  loss 0.8606176024705682  f1 score: 59.82345327404697
#  Test: accuracy 65.325 loss 0.8636 f1_score 59.587
# Saving..
# Model Training time:  63.539146900177 Hour:  0 Minute:  1 Second:  3
#  Test best accuracy: 65.32451923076923  Test best f1 score: 59.58651847414621
#
# Start of epoch NO: 7
# Epoch: [7][0/106]	Loss 1.0762 (1.0762)	accuracy 53.125 (53.125)	f1_score 50.966 (50.966)
# Epoch: [7][40/106]	Loss 0.6592 (0.7837)	accuracy 78.125 (68.636)	f1_score 74.225 (62.949)
# Epoch: [7][80/106]	Loss 1.0295 (0.7755)	accuracy 51.562 (69.464)	f1_score 43.903 (63.952)
#  Train: accuracy 69.2418790671611  loss 0.7746040633428855  f1 score: 63.455294515580896
#  Test: accuracy 41.226 loss 3.1760 f1_score 33.989
# Model Training time:  71.3789267539978 Hour:  0 Minute:  1 Second:  11
#  Test best accuracy: 65.32451923076923  Test best f1 score: 59.58651847414621
#
# Start of epoch NO: 8
# Epoch: [8][0/106]	Loss 0.7700 (0.7700)	accuracy 73.438 (73.438)	f1_score 71.238 (71.238)
# Epoch: [8][40/106]	Loss 0.5981 (0.8351)	accuracy 73.438 (67.530)	f1_score 63.524 (61.386)
# Epoch: [8][80/106]	Loss 0.5650 (0.7761)	accuracy 82.812 (69.309)	f1_score 74.102 (63.166)
#  Train: accuracy 68.3775682651022  loss 0.8085877620748665  f1 score: 62.82158158426768
#  Test: accuracy 45.373 loss 1.4795 f1_score 37.159
# Model Training time:  78.43343043327332 Hour:  0 Minute:  1 Second:  18
#  Test best accuracy: 65.32451923076923  Test best f1 score: 59.58651847414621
#
# Start of epoch NO: 9
# Epoch: [9][0/106]	Loss 0.5975 (0.5975)	accuracy 78.125 (78.125)	f1_score 72.727 (72.727)
# Epoch: [9][40/106]	Loss 0.6942 (0.7408)	accuracy 68.750 (70.389)	f1_score 62.392 (64.238)
# Epoch: [9][80/106]	Loss 0.6407 (0.7128)	accuracy 76.562 (72.029)	f1_score 73.929 (65.978)
#  Train: accuracy 71.6102443459907  loss 0.7174446890094355  f1 score: 65.55475166495087
#  Test: accuracy 60.877 loss 1.1416 f1_score 53.224
# Model Training time:  86.23997330665588 Hour:  0 Minute:  1 Second:  26
#  Test best accuracy: 65.32451923076923  Test best f1 score: 59.58651847414621
#
# Start of epoch NO: 10
# Epoch: [10][0/106]	Loss 0.7513 (0.7513)	accuracy 70.312 (70.312)	f1_score 61.035 (61.035)
# Epoch: [10][40/106]	Loss 0.5094 (0.6306)	accuracy 79.688 (75.762)	f1_score 75.999 (70.841)
# Epoch: [10][80/106]	Loss 0.8352 (0.6619)	accuracy 65.625 (74.286)	f1_score 64.127 (69.334)
#  Train: accuracy 75.09931499024454  loss 0.6449097484672455  f1 score: 69.91413509611981
#  Test: accuracy 62.380 loss 1.0592 f1_score 55.763
# Model Training time:  93.26245093345642 Hour:  0 Minute:  1 Second:  33
#  Test best accuracy: 65.32451923076923  Test best f1 score: 59.58651847414621
#
# Start of epoch NO: 11
# Epoch: [11][0/106]	Loss 0.7575 (0.7575)	accuracy 70.312 (70.312)	f1_score 66.715 (66.715)
# Epoch: [11][40/106]	Loss 0.3909 (0.6610)	accuracy 84.375 (73.971)	f1_score 81.190 (69.232)
# Epoch: [11][80/106]	Loss 0.5513 (0.6331)	accuracy 79.688 (75.907)	f1_score 72.498 (70.452)
#  Train: accuracy 74.41998972204988  loss 0.6559059318845679  f1 score: 69.14765304568637
#  Test: accuracy 55.709 loss 1.2816 f1_score 47.629
# Model Training time:  101.19423580169678 Hour:  0 Minute:  1 Second:  41
#  Test best accuracy: 65.32451923076923  Test best f1 score: 59.58651847414621
#
# Start of epoch NO: 12
# Epoch: [12][0/106]	Loss 0.7344 (0.7344)	accuracy 71.875 (71.875)	f1_score 70.260 (70.260)
# Epoch: [12][40/106]	Loss 0.6383 (0.6844)	accuracy 75.000 (73.361)	f1_score 76.097 (68.639)
# Epoch: [12][80/106]	Loss 0.5516 (0.6357)	accuracy 76.562 (75.502)	f1_score 73.946 (70.675)
#  Train: accuracy 74.61804260794916  loss 0.6576324566167495  f1 score: 69.91626819350179
#  Test: accuracy 68.870 loss 0.8344 f1_score 62.964
# Saving..
# Model Training time:  109.83619928359985 Hour:  0 Minute:  1 Second:  49
#  Test best accuracy: 68.8701923076923  Test best f1 score: 62.96355465480459
#
# Start of epoch NO: 13
# Epoch: [13][0/106]	Loss 0.5493 (0.5493)	accuracy 78.125 (78.125)	f1_score 59.331 (59.331)
# Epoch: [13][40/106]	Loss 0.6790 (0.6339)	accuracy 73.438 (76.867)	f1_score 73.928 (71.812)
# Epoch: [13][80/106]	Loss 0.4372 (0.5907)	accuracy 84.375 (78.144)	f1_score 76.635 (73.147)
#  Train: accuracy 77.59123071122924  loss 0.6102925756988415  f1 score: 71.99536041544121
#  Test: accuracy 66.346 loss 1.0392 f1_score 59.150
# Model Training time:  116.92834901809692 Hour:  0 Minute:  1 Second:  56
#  Test best accuracy: 68.8701923076923  Test best f1 score: 62.96355465480459
#
# Start of epoch NO: 14
# Epoch: [14][0/106]	Loss 0.4299 (0.4299)	accuracy 82.812 (82.812)	f1_score 81.723 (81.723)
# Epoch: [14][40/106]	Loss 0.4808 (0.5614)	accuracy 82.812 (78.849)	f1_score 79.299 (74.158)
# Epoch: [14][80/106]	Loss 0.6659 (0.5716)	accuracy 73.438 (78.742)	f1_score 72.884 (74.337)
#  Train: accuracy 79.31014752465175  loss 0.5514484512409156  f1 score: 74.92537189928095
#  Test: accuracy 63.762 loss 1.0191 f1_score 56.527
# Model Training time:  124.73278641700745 Hour:  0 Minute:  2 Second:  4
#  Test best accuracy: 68.8701923076923  Test best f1 score: 62.96355465480459
#
# Start of epoch NO: 15
# Epoch: [15][0/106]	Loss 0.6694 (0.6694)	accuracy 70.312 (70.312)	f1_score 64.536 (64.536)
# Epoch: [15][40/106]	Loss 0.4144 (0.5306)	accuracy 81.250 (80.259)	f1_score 79.831 (76.296)
# Epoch: [15][80/106]	Loss 0.4888 (0.5110)	accuracy 79.688 (80.961)	f1_score 75.953 (76.426)
#  Train: accuracy 80.33061376836439  loss 0.5240845218044065  f1 score: 76.30001489820263
#  Test: accuracy 67.608 loss 0.9707 f1_score 60.739
# Model Training time:  131.71601223945618 Hour:  0 Minute:  2 Second:  11
#  Test best accuracy: 68.8701923076923  Test best f1 score: 62.96355465480459
#
# Start of epoch NO: 16
# Epoch: [16][0/106]	Loss 0.3698 (0.3698)	accuracy 84.375 (84.375)	f1_score 77.532 (77.532)
# Epoch: [16][40/106]	Loss 0.4340 (0.5615)	accuracy 81.250 (77.363)	f1_score 77.975 (72.643)
# Epoch: [16][80/106]	Loss 0.4486 (0.5366)	accuracy 84.375 (78.954)	f1_score 77.193 (74.043)
#  Train: accuracy 78.30506181380188  loss 0.5490993725996882  f1 score: 73.41609817511807
#  Test: accuracy 42.188 loss 2.8268 f1_score 33.560
# Model Training time:  139.53223323822021 Hour:  0 Minute:  2 Second:  19
#  Test best accuracy: 68.8701923076923  Test best f1 score: 62.96355465480459
#
# Start of epoch NO: 17
# Epoch: [17][0/106]	Loss 0.5752 (0.5752)	accuracy 78.125 (78.125)	f1_score 69.567 (69.567)
# Epoch: [17][40/106]	Loss 0.4972 (0.5223)	accuracy 81.250 (79.840)	f1_score 78.550 (75.967)
# Epoch: [17][80/106]	Loss 0.7691 (0.5094)	accuracy 71.875 (80.999)	f1_score 59.617 (76.990)
#  Train: accuracy 80.12495949599568  loss 0.5248059776618541  f1 score: 75.97070928554275
#  Test: accuracy 57.392 loss 1.3019 f1_score 49.920
# Model Training time:  146.63865113258362 Hour:  0 Minute:  2 Second:  26
#  Test best accuracy: 68.8701923076923  Test best f1 score: 62.96355465480459
#
# Start of epoch NO: 18
# Epoch: [18][0/106]	Loss 0.4615 (0.4615)	accuracy 81.250 (81.250)	f1_score 80.801 (80.801)
# Epoch: [18][40/106]	Loss 0.7341 (0.4665)	accuracy 76.562 (82.546)	f1_score 63.880 (78.290)
# Epoch: [18][80/106]	Loss 0.6248 (0.5005)	accuracy 78.125 (81.366)	f1_score 74.403 (77.148)
#  Train: accuracy 81.83104830173761  loss 0.4865378702480276  f1 score: 77.70077098398022
#  Test: accuracy 40.565 loss 2.8703 f1_score 30.809
# Model Training time:  154.44447016716003 Hour:  0 Minute:  2 Second:  34
#  Test best accuracy: 68.8701923076923  Test best f1 score: 62.96355465480459
#
# Start of epoch NO: 19
# Epoch: [19][0/106]	Loss 0.4992 (0.4992)	accuracy 82.812 (82.812)	f1_score 84.721 (84.721)
# Epoch: [19][40/106]	Loss 0.5745 (0.4630)	accuracy 82.812 (83.079)	f1_score 83.965 (79.463)
# Epoch: [19][80/106]	Loss 0.3068 (0.4590)	accuracy 93.750 (83.063)	f1_score 93.641 (79.120)
#  Train: accuracy 82.764425697128  loss 0.4653347413104696  f1 score: 79.22349934110022
#  Test: accuracy 60.517 loss 1.0494 f1_score 54.815
# Model Training time:  161.95917105674744 Hour:  0 Minute:  2 Second:  41
#  Test best accuracy: 68.8701923076923  Test best f1 score: 62.96355465480459
#
# Start of epoch NO: 20
# Epoch: [20][0/106]	Loss 0.2151 (0.2151)	accuracy 93.750 (93.750)	f1_score 92.608 (92.608)
# Epoch: [20][40/106]	Loss 0.4131 (0.3810)	accuracy 82.812 (86.395)	f1_score 81.592 (83.650)
# Epoch: [20][80/106]	Loss 0.2619 (0.3678)	accuracy 93.750 (87.076)	f1_score 95.870 (84.298)
#  Train: accuracy 86.63735761242003  loss 0.37613598916216445  f1 score: 83.80521479600787
#  Test: accuracy 90.204 loss 0.2923 f1_score 88.478
# Saving..
# Model Training time:  169.33849215507507 Hour:  0 Minute:  2 Second:  49
#  Test best accuracy: 90.20432692307692  Test best f1 score: 88.47803308737114
#
# Start of epoch NO: 21
# Epoch: [21][0/106]	Loss 0.2887 (0.2887)	accuracy 90.625 (90.625)	f1_score 93.084 (93.084)
# Epoch: [21][40/106]	Loss 0.1809 (0.2942)	accuracy 98.438 (89.367)	f1_score 98.286 (86.776)
# Epoch: [21][80/106]	Loss 0.2281 (0.3008)	accuracy 90.625 (89.159)	f1_score 79.499 (86.696)
#  Train: accuracy 89.31996499460118  loss 0.2973422439485356  f1 score: 87.07584653424253
#  Test: accuracy 85.096 loss 0.3581 f1_score 82.665
# Model Training time:  177.20462679862976 Hour:  0 Minute:  2 Second:  57
#  Test best accuracy: 90.20432692307692  Test best f1 score: 88.47803308737114
#
# Start of epoch NO: 22
# Epoch: [22][0/106]	Loss 0.4172 (0.4172)	accuracy 81.250 (81.250)	f1_score 84.351 (84.351)
# Epoch: [22][40/106]	Loss 0.2492 (0.3143)	accuracy 92.188 (89.139)	f1_score 86.665 (86.999)
# Epoch: [22][80/106]	Loss 0.2496 (0.3111)	accuracy 89.062 (89.082)	f1_score 84.972 (87.061)
#  Train: accuracy 88.64512318873736  loss 0.3219473271357814  f1 score: 86.80319045216673
#  Test: accuracy 85.998 loss 0.3364 f1_score 83.226
# Model Training time:  184.24686861038208 Hour:  0 Minute:  3 Second:  4
#  Test best accuracy: 90.20432692307692  Test best f1 score: 88.47803308737114
#
# Start of epoch NO: 23
# Epoch: [23][0/106]	Loss 0.2548 (0.2548)	accuracy 93.750 (93.750)	f1_score 91.408 (91.408)
# Epoch: [23][40/106]	Loss 0.2150 (0.2836)	accuracy 92.188 (89.825)	f1_score 87.926 (86.786)
# Epoch: [23][80/106]	Loss 0.2979 (0.2918)	accuracy 89.062 (89.333)	f1_score 89.002 (86.866)
#  Train: accuracy 89.38987571210284  loss 0.2917663674620363  f1 score: 86.39481573213915
#  Test: accuracy 87.500 loss 0.3809 f1_score 85.555
# Model Training time:  192.0288553237915 Hour:  0 Minute:  3 Second:  12
#  Test best accuracy: 90.20432692307692  Test best f1 score: 88.47803308737114
#
# Start of epoch NO: 24
# Epoch: [24][0/106]	Loss 0.3173 (0.3173)	accuracy 85.938 (85.938)	f1_score 81.304 (81.304)
# Epoch: [24][40/106]	Loss 0.3211 (0.3066)	accuracy 87.500 (88.186)	f1_score 87.596 (86.043)
# Epoch: [24][80/106]	Loss 0.2531 (0.2921)	accuracy 89.062 (89.043)	f1_score 88.743 (86.905)
#  Train: accuracy 88.62183403702635  loss 0.3047981636783063  f1 score: 86.17712929342537
#  Test: accuracy 90.264 loss 0.2645 f1_score 88.177
# Saving..
# Model Training time:  199.05662178993225 Hour:  0 Minute:  3 Second:  19
#  Test best accuracy: 90.26442307692308  Test best f1 score: 88.17654576924942
#
# Start of epoch NO: 25
# Epoch: [25][0/106]	Loss 0.2270 (0.2270)	accuracy 90.625 (90.625)	f1_score 88.140 (88.140)
# Epoch: [25][40/106]	Loss 0.3866 (0.2695)	accuracy 84.375 (90.206)	f1_score 79.654 (87.901)
# Epoch: [25][80/106]	Loss 0.2632 (0.2736)	accuracy 85.938 (90.066)	f1_score 89.605 (87.351)
#  Train: accuracy 90.18828086496002  loss 0.2698621929996874  f1 score: 87.73730139227612
#  Test: accuracy 88.642 loss 0.3184 f1_score 86.462
# Model Training time:  207.46627640724182 Hour:  0 Minute:  3 Second:  27
#  Test best accuracy: 90.26442307692308  Test best f1 score: 88.17654576924942
#
# Start of epoch NO: 26
# Epoch: [26][0/106]	Loss 0.2031 (0.2031)	accuracy 95.312 (95.312)	f1_score 95.332 (95.332)
# Epoch: [26][40/106]	Loss 0.3280 (0.2648)	accuracy 87.500 (90.434)	f1_score 84.502 (88.713)
# Epoch: [26][80/106]	Loss 0.3722 (0.2656)	accuracy 87.500 (90.297)	f1_score 79.733 (88.373)
#  Train: accuracy 90.39658048353748  loss 0.2656429454375596  f1 score: 88.45135892200042
#  Test: accuracy 92.007 loss 0.2401 f1_score 90.510
# Saving..
# Model Training time:  214.9271788597107 Hour:  0 Minute:  3 Second:  34
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 27
# Epoch: [27][0/106]	Loss 0.2358 (0.2358)	accuracy 92.188 (92.188)	f1_score 82.971 (82.971)
# Epoch: [27][40/106]	Loss 0.2332 (0.2825)	accuracy 92.188 (89.596)	f1_score 90.404 (86.741)
# Epoch: [27][80/106]	Loss 0.2963 (0.2689)	accuracy 87.500 (90.027)	f1_score 82.045 (87.442)
#  Train: accuracy 90.05593513151491  loss 0.268483342845793  f1 score: 87.01339799825948
#  Test: accuracy 89.483 loss 0.2524 f1_score 88.142
# Model Training time:  222.43770051002502 Hour:  0 Minute:  3 Second:  42
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 28
# Epoch: [28][0/106]	Loss 0.2139 (0.2139)	accuracy 92.188 (92.188)	f1_score 89.524 (89.524)
# Epoch: [28][40/106]	Loss 0.2067 (0.2785)	accuracy 93.750 (89.825)	f1_score 93.667 (88.269)
# Epoch: [28][80/106]	Loss 0.2165 (0.2692)	accuracy 92.188 (90.181)	f1_score 88.396 (88.242)
#  Train: accuracy 90.07586518384342  loss 0.2725496162154256  f1 score: 88.16821384652465
#  Test: accuracy 90.024 loss 0.2717 f1_score 88.035
# Model Training time:  230.33506751060486 Hour:  0 Minute:  3 Second:  50
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 29
# Epoch: [29][0/106]	Loss 0.2439 (0.2439)	accuracy 92.188 (92.188)	f1_score 87.732 (87.732)
# Epoch: [29][40/106]	Loss 0.4715 (0.2687)	accuracy 75.000 (89.482)	f1_score 76.516 (87.238)
# Epoch: [29][80/106]	Loss 0.3084 (0.2640)	accuracy 81.250 (89.660)	f1_score 71.364 (87.379)
#  Train: accuracy 89.66779013785552  loss 0.2664416885081307  f1 score: 87.37442663595114
#  Test: accuracy 89.844 loss 0.3032 f1_score 88.275
# Model Training time:  237.44030380249023 Hour:  0 Minute:  3 Second:  57
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 30
# Epoch: [30][0/106]	Loss 0.2988 (0.2988)	accuracy 89.062 (89.062)	f1_score 86.553 (86.553)
# Epoch: [30][40/106]	Loss 0.2500 (0.2932)	accuracy 89.062 (88.681)	f1_score 89.946 (86.008)
# Epoch: [30][80/106]	Loss 0.2286 (0.2742)	accuracy 90.625 (89.468)	f1_score 92.409 (86.914)
#  Train: accuracy 89.37823705724132  loss 0.280280357502769  f1 score: 86.86834755362226
#  Test: accuracy 82.151 loss 0.6315 f1_score 78.957
# Model Training time:  246.44489741325378 Hour:  0 Minute:  4 Second:  6
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 31
# Epoch: [31][0/106]	Loss 0.2896 (0.2896)	accuracy 90.625 (90.625)	f1_score 90.457 (90.457)
# Epoch: [31][40/106]	Loss 0.1464 (0.2533)	accuracy 95.312 (90.854)	f1_score 87.407 (89.353)
# Epoch: [31][80/106]	Loss 0.1564 (0.2528)	accuracy 95.312 (90.664)	f1_score 94.300 (88.806)
#  Train: accuracy 90.66034793235865  loss 0.2570952141364121  f1 score: 89.10563768244593
#  Test: accuracy 85.938 loss 0.3683 f1_score 83.577
# Model Training time:  253.50303554534912 Hour:  0 Minute:  4 Second:  13
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 32
# Epoch: [32][0/106]	Loss 0.2810 (0.2810)	accuracy 90.625 (90.625)	f1_score 85.166 (85.166)
# Epoch: [32][40/106]	Loss 0.3126 (0.2449)	accuracy 92.188 (91.235)	f1_score 90.750 (88.623)
# Epoch: [32][80/106]	Loss 0.1924 (0.2498)	accuracy 92.188 (90.972)	f1_score 89.470 (88.683)
#  Train: accuracy 91.46990472939574  loss 0.24438900213409925  f1 score: 89.06177978641054
#  Test: accuracy 84.255 loss 0.3504 f1_score 81.494
# Model Training time:  261.4454665184021 Hour:  0 Minute:  4 Second:  21
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 33
# Epoch: [33][0/106]	Loss 0.1301 (0.1301)	accuracy 95.312 (95.312)	f1_score 91.212 (91.212)
# Epoch: [33][40/106]	Loss 0.2137 (0.2414)	accuracy 89.062 (91.273)	f1_score 87.101 (89.323)
# Epoch: [33][80/106]	Loss 0.2251 (0.2442)	accuracy 90.625 (90.683)	f1_score 86.620 (88.780)
#  Train: accuracy 91.3174827652098  loss 0.23675504472431333  f1 score: 89.20423202159313
#  Test: accuracy 88.702 loss 0.2876 f1_score 86.856
# Model Training time:  268.6965353488922 Hour:  0 Minute:  4 Second:  28
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 34
# Epoch: [34][0/106]	Loss 0.2939 (0.2939)	accuracy 85.938 (85.938)	f1_score 82.665 (82.665)
# Epoch: [34][40/106]	Loss 0.2031 (0.2565)	accuracy 93.750 (90.206)	f1_score 88.937 (88.066)
# Epoch: [34][80/106]	Loss 0.2571 (0.2502)	accuracy 93.750 (90.451)	f1_score 86.046 (88.365)
#  Train: accuracy 90.45078399814149  loss 0.25027657567414535  f1 score: 88.07850388872652
#  Test: accuracy 90.925 loss 0.2151 f1_score 89.021
# Model Training time:  276.4259810447693 Hour:  0 Minute:  4 Second:  36
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 35
# Epoch: [35][0/106]	Loss 0.2445 (0.2445)	accuracy 93.750 (93.750)	f1_score 93.878 (93.878)
# Epoch: [35][40/106]	Loss 0.2730 (0.2470)	accuracy 89.062 (90.091)	f1_score 85.128 (88.381)
# Epoch: [35][80/106]	Loss 0.5746 (0.2488)	accuracy 76.562 (90.336)	f1_score 68.480 (87.967)
#  Train: accuracy 90.40257187993618  loss 0.24659399835456666  f1 score: 88.60894520033517
#  Test: accuracy 87.139 loss 0.3744 f1_score 84.799
# Model Training time:  284.11812376976013 Hour:  0 Minute:  4 Second:  44
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 36
# Epoch: [36][0/106]	Loss 0.1960 (0.1960)	accuracy 92.188 (92.188)	f1_score 90.841 (90.841)
# Epoch: [36][40/106]	Loss 0.2678 (0.2570)	accuracy 89.062 (90.854)	f1_score 91.916 (89.217)
# Epoch: [36][80/106]	Loss 0.3123 (0.2511)	accuracy 89.062 (90.895)	f1_score 81.766 (89.063)
#  Train: accuracy 90.86721702917684  loss 0.25079865522576006  f1 score: 88.93450229034251
#  Test: accuracy 84.195 loss 0.4769 f1_score 81.191
# Model Training time:  291.3642110824585 Hour:  0 Minute:  4 Second:  51
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 37
# Epoch: [37][0/106]	Loss 0.1876 (0.1876)	accuracy 93.750 (93.750)	f1_score 89.874 (89.874)
# Epoch: [37][40/106]	Loss 0.1938 (0.2373)	accuracy 93.750 (91.578)	f1_score 90.242 (89.320)
# Epoch: [37][80/106]	Loss 0.3965 (0.2403)	accuracy 84.375 (91.435)	f1_score 83.849 (89.221)
#  Train: accuracy 91.02448806140043  loss 0.245290505488745  f1 score: 88.74575897387477
#  Test: accuracy 87.500 loss 0.2888 f1_score 84.962
# Model Training time:  299.29351902008057 Hour:  0 Minute:  4 Second:  59
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 38
# Epoch: [38][0/106]	Loss 0.2970 (0.2970)	accuracy 89.062 (89.062)	f1_score 85.912 (85.912)
# Epoch: [38][40/106]	Loss 0.1705 (0.2491)	accuracy 93.750 (90.968)	f1_score 90.166 (88.492)
# Epoch: [38][80/106]	Loss 0.2077 (0.2482)	accuracy 93.750 (90.799)	f1_score 91.014 (88.476)
#  Train: accuracy 90.77105279967947  loss 0.250019471679838  f1 score: 88.30760140989979
#  Test: accuracy 90.986 loss 0.2391 f1_score 89.009
# Model Training time:  306.3183391094208 Hour:  0 Minute:  5 Second:  6
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 39
# Epoch: [39][0/106]	Loss 0.2174 (0.2174)	accuracy 90.625 (90.625)	f1_score 86.832 (86.832)
# Epoch: [39][40/106]	Loss 0.1906 (0.2492)	accuracy 92.188 (91.006)	f1_score 91.385 (89.053)
# Epoch: [39][80/106]	Loss 0.2973 (0.2373)	accuracy 87.500 (91.223)	f1_score 79.167 (88.722)
#  Train: accuracy 91.06095436812717  loss 0.24357696599423131  f1 score: 88.85607947168442
#  Test: accuracy 85.397 loss 0.4050 f1_score 81.875
# Model Training time:  314.202436208725 Hour:  0 Minute:  5 Second:  14
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 40
# Epoch: [40][0/106]	Loss 0.2646 (0.2646)	accuracy 87.500 (87.500)	f1_score 82.001 (82.001)
# Epoch: [40][40/106]	Loss 0.4635 (0.2240)	accuracy 78.125 (91.883)	f1_score 82.143 (89.393)
# Epoch: [40][80/106]	Loss 0.2972 (0.2342)	accuracy 84.375 (91.397)	f1_score 84.320 (89.477)
#  Train: accuracy 91.6031738979813  loss 0.22740419145380583  f1 score: 89.17152576529517
#  Test: accuracy 80.469 loss 0.6159 f1_score 76.103
# Model Training time:  321.3294560909271 Hour:  0 Minute:  5 Second:  21
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 41
# Epoch: [41][0/106]	Loss 0.1283 (0.1283)	accuracy 95.312 (95.312)	f1_score 90.152 (90.152)
# Epoch: [41][40/106]	Loss 0.4942 (0.2164)	accuracy 79.688 (92.264)	f1_score 81.329 (89.584)
# Epoch: [41][80/106]	Loss 0.1847 (0.2240)	accuracy 93.750 (91.975)	f1_score 91.270 (89.839)
#  Train: accuracy 92.48710037961067  loss 0.2121882956009596  f1 score: 90.02769189515845
#  Test: accuracy 89.724 loss 0.2373 f1_score 87.808
# Model Training time:  329.284645318985 Hour:  0 Minute:  5 Second:  29
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 42
# Epoch: [42][0/106]	Loss 0.2767 (0.2767)	accuracy 87.500 (87.500)	f1_score 83.219 (83.219)
# Epoch: [42][40/106]	Loss 0.1322 (0.2264)	accuracy 96.875 (91.616)	f1_score 93.348 (89.570)
# Epoch: [42][80/106]	Loss 0.1846 (0.2239)	accuracy 90.625 (91.647)	f1_score 88.798 (89.876)
#  Train: accuracy 91.69243443152504  loss 0.22430111389174398  f1 score: 89.79362023796253
#  Test: accuracy 89.724 loss 0.2528 f1_score 87.838
# Model Training time:  336.86035895347595 Hour:  0 Minute:  5 Second:  36
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 43
# Epoch: [43][0/106]	Loss 0.1318 (0.1318)	accuracy 95.312 (95.312)	f1_score 91.546 (91.546)
# Epoch: [43][40/106]	Loss 0.2933 (0.2077)	accuracy 89.062 (92.530)	f1_score 90.910 (90.318)
# Epoch: [43][80/106]	Loss 0.1306 (0.2226)	accuracy 95.312 (91.647)	f1_score 94.161 (89.502)
#  Train: accuracy 92.26693387136329  loss 0.2101195197503844  f1 score: 90.13426579137568
#  Test: accuracy 87.139 loss 0.4113 f1_score 85.122
# Model Training time:  344.3216509819031 Hour:  0 Minute:  5 Second:  44
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 44
# Epoch: [44][0/106]	Loss 0.1557 (0.1557)	accuracy 92.188 (92.188)	f1_score 90.453 (90.453)
# Epoch: [44][40/106]	Loss 0.1409 (0.2429)	accuracy 95.312 (90.739)	f1_score 91.515 (88.399)
# Epoch: [44][80/106]	Loss 0.2842 (0.2322)	accuracy 90.625 (91.262)	f1_score 90.414 (89.092)
#  Train: accuracy 90.9367096601113  loss 0.23926072570034798  f1 score: 88.5480470010883
#  Test: accuracy 89.002 loss 0.2998 f1_score 86.515
# Model Training time:  352.2615382671356 Hour:  0 Minute:  5 Second:  52
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 45
# Epoch: [45][0/106]	Loss 0.2518 (0.2518)	accuracy 90.625 (90.625)	f1_score 86.227 (86.227)
# Epoch: [45][40/106]	Loss 0.2330 (0.2267)	accuracy 87.500 (91.502)	f1_score 78.908 (89.276)
# Epoch: [45][80/106]	Loss 0.1912 (0.2336)	accuracy 92.188 (91.281)	f1_score 92.955 (89.569)
#  Train: accuracy 91.54499449493244  loss 0.22832563314512522  f1 score: 89.58706730355533
#  Test: accuracy 90.865 loss 0.2336 f1_score 89.161
# Model Training time:  359.38805079460144 Hour:  0 Minute:  5 Second:  59
#  Test best accuracy: 92.00721153846153  Test best f1 score: 90.5097291177418
#
# Start of epoch NO: 46
# Epoch: [46][0/106]	Loss 0.2449 (0.2449)	accuracy 93.750 (93.750)	f1_score 92.273 (92.273)
# Epoch: [46][40/106]	Loss 0.2162 (0.2417)	accuracy 90.625 (91.463)	f1_score 91.190 (89.262)
# Epoch: [46][80/106]	Loss 0.2201 (0.2334)	accuracy 92.188 (91.416)	f1_score 91.717 (89.394)
#  Train: accuracy 91.30881782276388  loss 0.24039694973897807  f1 score: 89.1345176521684
#  Test: accuracy 92.849 loss 0.2183 f1_score 91.000
# Saving..
# Model Training time:  367.4222960472107 Hour:  0 Minute:  6 Second:  7
#  Test best accuracy: 92.8485576923077  Test best f1 score: 90.99992509111652
#
# Start of epoch NO: 47
# Epoch: [47][0/106]	Loss 0.1482 (0.1482)	accuracy 95.312 (95.312)	f1_score 94.845 (94.845)
# Epoch: [47][40/106]	Loss 0.2212 (0.2160)	accuracy 95.312 (92.226)	f1_score 96.008 (90.204)
# Epoch: [47][80/106]	Loss 0.2652 (0.2150)	accuracy 90.625 (92.188)	f1_score 87.900 (89.962)
#  Train: accuracy 92.06283864376763  loss 0.21557311130680762  f1 score: 89.82786256565942
#  Test: accuracy 91.587 loss 0.2317 f1_score 89.876
# Model Training time:  374.7202801704407 Hour:  0 Minute:  6 Second:  14
#  Test best accuracy: 92.8485576923077  Test best f1 score: 90.99992509111652
#
# Start of epoch NO: 48
# Epoch: [48][0/106]	Loss 0.1192 (0.1192)	accuracy 96.875 (96.875)	f1_score 92.987 (92.987)
# Epoch: [48][40/106]	Loss 0.1189 (0.2029)	accuracy 96.875 (93.026)	f1_score 95.411 (91.115)
# Epoch: [48][80/106]	Loss 0.2412 (0.2113)	accuracy 89.062 (92.149)	f1_score 86.553 (90.140)
#  Train: accuracy 92.56922399877425  loss 0.20787820209713012  f1 score: 90.55987348830628
#  Test: accuracy 80.108 loss 0.7080 f1_score 75.803
# Model Training time:  384.0107071399689 Hour:  0 Minute:  6 Second:  24
#  Test best accuracy: 92.8485576923077  Test best f1 score: 90.99992509111652
#
# Start of epoch NO: 49
# Epoch: [49][0/106]	Loss 0.2232 (0.2232)	accuracy 89.062 (89.062)	f1_score 87.277 (87.277)
# Epoch: [49][40/106]	Loss 0.2695 (0.2118)	accuracy 89.062 (92.111)	f1_score 90.590 (90.156)
# Epoch: [49][80/106]	Loss 0.2339 (0.2160)	accuracy 93.750 (92.014)	f1_score 91.876 (90.174)
#  Train: accuracy 92.21268094012697  loss 0.20997452816726994  f1 score: 90.38303104947518
#  Test: accuracy 92.248 loss 0.2148 f1_score 90.955
# Model Training time:  391.59339022636414 Hour:  0 Minute:  6 Second:  31
#  Test best accuracy: 92.8485576923077  Test best f1 score: 90.99992509111652
#
# Start of epoch NO: 50
# Epoch: [50][0/106]	Loss 0.2429 (0.2429)	accuracy 90.625 (90.625)	f1_score 90.150 (90.150)
# Epoch: [50][40/106]	Loss 0.1514 (0.2005)	accuracy 95.312 (93.026)	f1_score 94.924 (91.567)
# Epoch: [50][80/106]	Loss 0.2295 (0.2094)	accuracy 92.188 (92.458)	f1_score 87.403 (90.613)
#  Train: accuracy 92.82239616547538  loss 0.20308283977048167  f1 score: 91.24334284533501
#  Test: accuracy 90.925 loss 0.2258 f1_score 89.428
# Model Training time:  399.1978175640106 Hour:  0 Minute:  6 Second:  39
#  Test best accuracy: 92.8485576923077  Test best f1 score: 90.99992509111652
#
# Start of epoch NO: 51
# Epoch: [51][0/106]	Loss 0.1655 (0.1655)	accuracy 95.312 (95.312)	f1_score 92.904 (92.904)
# Epoch: [51][40/106]	Loss 0.3539 (0.2038)	accuracy 87.500 (92.721)	f1_score 89.426 (90.812)
# Epoch: [51][80/106]	Loss 0.1644 (0.2115)	accuracy 95.312 (92.130)	f1_score 95.411 (90.413)
#  Train: accuracy 92.7526358882851  loss 0.202467671284561  f1 score: 90.8478298940601
#  Test: accuracy 81.791 loss 0.6641 f1_score 76.941
# Model Training time:  407.21215867996216 Hour:  0 Minute:  6 Second:  47
#  Test best accuracy: 92.8485576923077  Test best f1 score: 90.99992509111652
#
# Start of epoch NO: 52
# Epoch: [52][0/106]	Loss 0.1877 (0.1877)	accuracy 93.750 (93.750)	f1_score 88.002 (88.002)
# Epoch: [52][40/106]	Loss 0.1811 (0.1985)	accuracy 90.625 (92.912)	f1_score 87.755 (91.134)
# Epoch: [52][80/106]	Loss 0.2982 (0.2073)	accuracy 89.062 (92.303)	f1_score 86.162 (90.514)
#  Train: accuracy 92.71210193614935  loss 0.20192048412813177  f1 score: 90.90401871569617
#  Test: accuracy 93.810 loss 0.2062 f1_score 92.885
# Saving..
# Model Training time:  414.422167301178 Hour:  0 Minute:  6 Second:  54
#  Test best accuracy: 93.81009615384616  Test best f1 score: 92.88515750033551
#
# Start of epoch NO: 53
# Epoch: [53][0/106]	Loss 0.1103 (0.1103)	accuracy 95.312 (95.312)	f1_score 92.424 (92.424)
# Epoch: [53][40/106]	Loss 0.0967 (0.2002)	accuracy 96.875 (93.026)	f1_score 92.381 (91.602)
# Epoch: [53][80/106]	Loss 0.3174 (0.2151)	accuracy 87.500 (92.207)	f1_score 80.635 (90.588)
#  Train: accuracy 92.84583467502996  loss 0.2037107204561188  f1 score: 91.24279860967026
#  Test: accuracy 92.728 loss 0.2021 f1_score 91.002
# Model Training time:  422.39931058883667 Hour:  0 Minute:  7 Second:  2
#  Test best accuracy: 93.81009615384616  Test best f1 score: 92.88515750033551
#
# Start of epoch NO: 54
# Epoch: [54][0/106]	Loss 0.1532 (0.1532)	accuracy 96.875 (96.875)	f1_score 93.287 (93.287)
# Epoch: [54][40/106]	Loss 0.2337 (0.2086)	accuracy 92.188 (92.607)	f1_score 87.778 (90.944)
# Epoch: [54][80/106]	Loss 0.1556 (0.2019)	accuracy 95.312 (92.554)	f1_score 92.088 (90.508)
#  Train: accuracy 92.49527016631606  loss 0.20841807546298047  f1 score: 90.57816443484694
#  Test: accuracy 90.565 loss 0.2281 f1_score 88.769
# Model Training time:  429.51524233818054 Hour:  0 Minute:  7 Second:  9
#  Test best accuracy: 93.81009615384616  Test best f1 score: 92.88515750033551
#
# Start of epoch NO: 55
# Epoch: [55][0/106]	Loss 0.2575 (0.2575)	accuracy 89.062 (89.062)	f1_score 87.371 (87.371)
# Epoch: [55][40/106]	Loss 0.1492 (0.2258)	accuracy 95.312 (91.159)	f1_score 91.667 (89.944)
# Epoch: [55][80/106]	Loss 0.2004 (0.2109)	accuracy 92.188 (91.898)	f1_score 90.758 (90.300)
#  Train: accuracy 91.50576400443204  loss 0.2209568934591354  f1 score: 90.15439823288962
#  Test: accuracy 93.990 loss 0.1869 f1_score 92.251
# Saving..
# Model Training time:  437.5297613143921 Hour:  0 Minute:  7 Second:  17
#  Test best accuracy: 93.99038461538461  Test best f1 score: 92.25148954004652
#
# Start of epoch NO: 56
# Epoch: [56][0/106]	Loss 0.1916 (0.1916)	accuracy 90.625 (90.625)	f1_score 84.091 (84.091)
# Epoch: [56][40/106]	Loss 0.1559 (0.2517)	accuracy 95.312 (89.901)	f1_score 90.714 (87.705)
# Epoch: [56][80/106]	Loss 0.1556 (0.2412)	accuracy 96.875 (90.876)	f1_score 93.391 (88.870)
#  Train: accuracy 90.33672183587385  loss 0.2463558637641054  f1 score: 88.42502593902248
#  Test: accuracy 91.947 loss 0.2087 f1_score 89.389
# Model Training time:  444.9963254928589 Hour:  0 Minute:  7 Second:  24
#  Test best accuracy: 93.99038461538461  Test best f1 score: 92.25148954004652
#
# Start of epoch NO: 57
# Epoch: [57][0/106]	Loss 0.2798 (0.2798)	accuracy 87.500 (87.500)	f1_score 89.834 (89.834)
# Epoch: [57][40/106]	Loss 0.2787 (0.2025)	accuracy 85.938 (92.607)	f1_score 85.166 (90.417)
# Epoch: [57][80/106]	Loss 0.2197 (0.2069)	accuracy 92.188 (92.207)	f1_score 89.784 (90.100)
#  Train: accuracy 92.28904662124745  loss 0.20784168284714788  f1 score: 90.372148235701
#  Test: accuracy 88.101 loss 0.3527 f1_score 85.540
# Model Training time:  452.60953974723816 Hour:  0 Minute:  7 Second:  32
#  Test best accuracy: 93.99038461538461  Test best f1 score: 92.25148954004652
#
# Start of epoch NO: 58
# Epoch: [58][0/106]	Loss 0.0861 (0.0861)	accuracy 98.438 (98.438)	f1_score 94.805 (94.805)
# Epoch: [58][40/106]	Loss 0.2924 (0.2075)	accuracy 89.062 (91.692)	f1_score 89.577 (89.786)
# Epoch: [58][80/106]	Loss 0.2624 (0.2058)	accuracy 92.188 (92.149)	f1_score 83.504 (90.338)
#  Train: accuracy 92.37370425759678  loss 0.1989736452465815  f1 score: 90.31296637180786
#  Test: accuracy 85.817 loss 0.4933 f1_score 82.804
# Model Training time:  460.6471710205078 Hour:  0 Minute:  7 Second:  40
#  Test best accuracy: 93.99038461538461  Test best f1 score: 92.25148954004652
#
# Start of epoch NO: 59
# Epoch: [59][0/106]	Loss 0.2583 (0.2583)	accuracy 90.625 (90.625)	f1_score 90.393 (90.393)
# Epoch: [59][40/106]	Loss 0.2312 (0.2052)	accuracy 89.062 (92.416)	f1_score 87.067 (90.885)
# Epoch: [59][80/106]	Loss 0.1930 (0.2148)	accuracy 92.188 (92.245)	f1_score 89.065 (90.651)
#  Train: accuracy 92.70840486717908  loss 0.2016429460545858  f1 score: 91.08875493852415
#  Test: accuracy 85.877 loss 0.3640 f1_score 82.116
# Model Training time:  467.7625410556793 Hour:  0 Minute:  7 Second:  47
#  Test best accuracy: 93.99038461538461  Test best f1 score: 92.25148954004652
#
# Start of epoch NO: 60
# Epoch: [60][0/106]	Loss 0.2846 (0.2846)	accuracy 89.062 (89.062)	f1_score 82.730 (82.730)
# Epoch: [60][40/106]	Loss 0.2770 (0.1877)	accuracy 90.625 (92.759)	f1_score 91.567 (90.538)
# Epoch: [60][80/106]	Loss 0.1457 (0.1874)	accuracy 90.625 (92.670)	f1_score 86.667 (91.073)
#  Train: accuracy 92.65800219344158  loss 0.19060393477747942  f1 score: 90.67658674707113
#  Test: accuracy 94.050 loss 0.1732 f1_score 92.812
# Saving..
# Model Training time:  475.76252818107605 Hour:  0 Minute:  7 Second:  55
#  Test best accuracy: 94.05048076923077  Test best f1 score: 92.81214468865093
#
# Start of epoch NO: 61
# Epoch: [61][0/106]	Loss 0.2562 (0.2562)	accuracy 93.750 (93.750)	f1_score 95.550 (95.550)
# Epoch: [61][40/106]	Loss 0.1500 (0.2044)	accuracy 92.188 (92.645)	f1_score 87.256 (91.467)
# Epoch: [61][80/106]	Loss 0.1173 (0.2073)	accuracy 98.438 (92.419)	f1_score 97.732 (90.842)
#  Train: accuracy 92.77835696670638  loss 0.20168457988393312  f1 score: 91.66269677857365
#  Test: accuracy 82.091 loss 0.4849 f1_score 77.412
# Model Training time:  482.88644099235535 Hour:  0 Minute:  8 Second:  2
#  Test best accuracy: 94.05048076923077  Test best f1 score: 92.81214468865093
#
# Start of epoch NO: 62
# Epoch: [62][0/106]	Loss 0.1717 (0.1717)	accuracy 93.750 (93.750)	f1_score 92.424 (92.424)
# Epoch: [62][40/106]	Loss 0.2647 (0.1922)	accuracy 85.938 (92.912)	f1_score 88.841 (90.614)
# Epoch: [62][80/106]	Loss 0.2370 (0.2003)	accuracy 89.062 (92.843)	f1_score 90.400 (90.612)
#  Train: accuracy 92.74528422602124  loss 0.19857150698990625  f1 score: 90.69280974343745
#  Test: accuracy 91.046 loss 0.2269 f1_score 89.798
# Model Training time:  490.757931470871 Hour:  0 Minute:  8 Second:  10
#  Test best accuracy: 94.05048076923077  Test best f1 score: 92.81214468865093
#
# Start of epoch NO: 63
# Epoch: [63][0/106]	Loss 0.1302 (0.1302)	accuracy 95.312 (95.312)	f1_score 95.530 (95.530)
# Epoch: [63][40/106]	Loss 0.1621 (0.1813)	accuracy 93.750 (93.750)	f1_score 93.519 (92.077)
# Epoch: [63][80/106]	Loss 0.2576 (0.1872)	accuracy 89.062 (92.978)	f1_score 89.056 (91.401)
#  Train: accuracy 93.5886469385209  loss 0.1790488774857793  f1 score: 91.80511935822847
#  Test: accuracy 91.947 loss 0.2306 f1_score 90.728
# Model Training time:  498.2100524902344 Hour:  0 Minute:  8 Second:  18
#  Test best accuracy: 94.05048076923077  Test best f1 score: 92.81214468865093
#
# Start of epoch NO: 64
# Epoch: [64][0/106]	Loss 0.1751 (0.1751)	accuracy 93.750 (93.750)	f1_score 92.904 (92.904)
# Epoch: [64][40/106]	Loss 0.2432 (0.1954)	accuracy 92.188 (92.912)	f1_score 88.602 (90.681)
# Epoch: [64][80/106]	Loss 0.2422 (0.1972)	accuracy 89.062 (92.766)	f1_score 87.294 (90.369)
#  Train: accuracy 92.7147834583836  loss 0.1979894127692976  f1 score: 90.28192023831483
#  Test: accuracy 87.740 loss 0.2892 f1_score 85.788
# Model Training time:  505.82705783843994 Hour:  0 Minute:  8 Second:  25
#  Test best accuracy: 94.05048076923077  Test best f1 score: 92.81214468865093
#
# Start of epoch NO: 65
# Epoch: [65][0/106]	Loss 0.1362 (0.1362)	accuracy 93.750 (93.750)	f1_score 93.685 (93.685)
# Epoch: [65][40/106]	Loss 0.1169 (0.1835)	accuracy 98.438 (93.636)	f1_score 98.846 (92.333)
# Epoch: [65][80/106]	Loss 0.2839 (0.1933)	accuracy 90.625 (93.113)	f1_score 91.642 (91.599)
#  Train: accuracy 93.48765848563734  loss 0.18490422287773556  f1 score: 92.10199365556656
#  Test: accuracy 94.171 loss 0.1874 f1_score 92.968
# Saving..
# Model Training time:  515.041978597641 Hour:  0 Minute:  8 Second:  35
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 66
# Epoch: [66][0/106]	Loss 0.2092 (0.2092)	accuracy 90.625 (90.625)	f1_score 90.787 (90.787)
# Epoch: [66][40/106]	Loss 0.2606 (0.1944)	accuracy 90.625 (92.950)	f1_score 89.261 (91.416)
# Epoch: [66][80/106]	Loss 0.2191 (0.1902)	accuracy 89.062 (92.901)	f1_score 89.017 (91.181)
#  Train: accuracy 92.96182557854223  loss 0.19014447063019851  f1 score: 91.01391079723881
#  Test: accuracy 82.031 loss 0.7291 f1_score 77.489
# Model Training time:  522.1956057548523 Hour:  0 Minute:  8 Second:  42
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 67
# Epoch: [67][0/106]	Loss 0.1858 (0.1858)	accuracy 92.188 (92.188)	f1_score 88.155 (88.155)
# Epoch: [67][40/106]	Loss 0.2733 (0.2118)	accuracy 89.062 (91.578)	f1_score 79.339 (89.637)
# Epoch: [67][80/106]	Loss 0.1328 (0.1970)	accuracy 93.750 (92.130)	f1_score 92.857 (90.195)
#  Train: accuracy 91.76707279591481  loss 0.20616793674750447  f1 score: 89.76706254829764
#  Test: accuracy 89.784 loss 0.2462 f1_score 87.889
# Model Training time:  530.0972716808319 Hour:  0 Minute:  8 Second:  50
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 68
# Epoch: [68][0/106]	Loss 0.1917 (0.1917)	accuracy 93.750 (93.750)	f1_score 94.161 (94.161)
# Epoch: [68][40/106]	Loss 0.1456 (0.1946)	accuracy 96.875 (93.026)	f1_score 97.177 (91.304)
# Epoch: [68][80/106]	Loss 0.2376 (0.2051)	accuracy 92.188 (92.477)	f1_score 88.407 (90.590)
#  Train: accuracy 93.17668809745257  loss 0.1925736349087089  f1 score: 91.26313752870864
#  Test: accuracy 93.389 loss 0.1863 f1_score 91.952
# Model Training time:  537.2244644165039 Hour:  0 Minute:  8 Second:  57
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 69
# Epoch: [69][0/106]	Loss 0.1790 (0.1790)	accuracy 93.750 (93.750)	f1_score 90.531 (90.531)
# Epoch: [69][40/106]	Loss 0.1925 (0.1895)	accuracy 93.750 (93.674)	f1_score 95.297 (91.559)
# Epoch: [69][80/106]	Loss 0.2124 (0.1904)	accuracy 92.188 (93.326)	f1_score 93.114 (91.401)
#  Train: accuracy 93.4558806957107  loss 0.18886539645302092  f1 score: 91.42095573687672
#  Test: accuracy 92.127 loss 0.1983 f1_score 90.280
# Model Training time:  545.193009853363 Hour:  0 Minute:  9 Second:  5
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 70
# Epoch: [70][0/106]	Loss 0.1907 (0.1907)	accuracy 93.750 (93.750)	f1_score 90.866 (90.866)
# Epoch: [70][40/106]	Loss 0.2340 (0.2200)	accuracy 90.625 (91.997)	f1_score 88.040 (90.627)
# Epoch: [70][80/106]	Loss 0.2905 (0.2133)	accuracy 92.188 (92.265)	f1_score 91.185 (90.661)
#  Train: accuracy 92.33615384192522  loss 0.20988944023025707  f1 score: 90.8646908722338
#  Test: accuracy 87.380 loss 0.3219 f1_score 84.851
# Model Training time:  552.7131729125977 Hour:  0 Minute:  9 Second:  12
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 71
# Epoch: [71][0/106]	Loss 0.1918 (0.1918)	accuracy 96.875 (96.875)	f1_score 93.605 (93.605)
# Epoch: [71][40/106]	Loss 0.1799 (0.1887)	accuracy 93.750 (92.988)	f1_score 91.082 (91.257)
# Epoch: [71][80/106]	Loss 0.2413 (0.1978)	accuracy 93.750 (92.400)	f1_score 93.236 (90.556)
#  Train: accuracy 92.81883924412848  loss 0.19249171215344899  f1 score: 90.71419460986809
#  Test: accuracy 89.603 loss 0.2446 f1_score 87.432
# Model Training time:  560.266786813736 Hour:  0 Minute:  9 Second:  20
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 72
# Epoch: [72][0/106]	Loss 0.1178 (0.1178)	accuracy 98.438 (98.438)	f1_score 98.367 (98.367)
# Epoch: [72][40/106]	Loss 0.1904 (0.1736)	accuracy 93.750 (93.902)	f1_score 90.930 (91.645)
# Epoch: [72][80/106]	Loss 0.1798 (0.1775)	accuracy 93.750 (93.403)	f1_score 91.004 (91.626)
#  Train: accuracy 93.80780645534665  loss 0.17503602025967502  f1 score: 91.79629617899907
#  Test: accuracy 88.401 loss 0.3549 f1_score 85.588
# Model Training time:  568.2491972446442 Hour:  0 Minute:  9 Second:  28
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 73
# Epoch: [73][0/106]	Loss 0.1498 (0.1498)	accuracy 95.312 (95.312)	f1_score 94.203 (94.203)
# Epoch: [73][40/106]	Loss 0.1324 (0.1747)	accuracy 96.875 (93.521)	f1_score 94.697 (91.861)
# Epoch: [73][80/106]	Loss 0.1756 (0.1886)	accuracy 92.188 (93.094)	f1_score 92.297 (91.322)
#  Train: accuracy 93.17838936619015  loss 0.18316466302781978  f1 score: 91.63432027365357
#  Test: accuracy 92.488 loss 0.2059 f1_score 91.411
# Model Training time:  575.3733961582184 Hour:  0 Minute:  9 Second:  35
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 74
# Epoch: [74][0/106]	Loss 0.1856 (0.1856)	accuracy 93.750 (93.750)	f1_score 89.275 (89.275)
# Epoch: [74][40/106]	Loss 0.1432 (0.1820)	accuracy 98.438 (93.559)	f1_score 98.095 (91.958)
# Epoch: [74][80/106]	Loss 0.2712 (0.1938)	accuracy 87.500 (92.728)	f1_score 86.061 (90.610)
#  Train: accuracy 93.13428134067935  loss 0.18642005501099188  f1 score: 91.10209399563682
#  Test: accuracy 87.740 loss 0.4567 f1_score 84.865
# Model Training time:  583.3326625823975 Hour:  0 Minute:  9 Second:  43
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 75
# Epoch: [75][0/106]	Loss 0.2216 (0.2216)	accuracy 90.625 (90.625)	f1_score 88.942 (88.942)
# Epoch: [75][40/106]	Loss 0.1961 (0.1954)	accuracy 90.625 (92.188)	f1_score 83.176 (90.388)
# Epoch: [75][80/106]	Loss 0.1843 (0.1877)	accuracy 90.625 (92.843)	f1_score 91.863 (91.259)
#  Train: accuracy 92.60072573285936  loss 0.18842930925783735  f1 score: 90.89752583456657
#  Test: accuracy 92.849 loss 0.1825 f1_score 92.246
# Model Training time:  590.4716358184814 Hour:  0 Minute:  9 Second:  50
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 76
# Epoch: [76][0/106]	Loss 0.2498 (0.2498)	accuracy 92.188 (92.188)	f1_score 89.238 (89.238)
# Epoch: [76][40/106]	Loss 0.3849 (0.1851)	accuracy 89.062 (93.064)	f1_score 83.761 (91.135)
# Epoch: [76][80/106]	Loss 0.2432 (0.1902)	accuracy 92.188 (92.515)	f1_score 90.530 (90.852)
#  Train: accuracy 92.71756353429623  loss 0.19068708801346043  f1 score: 90.91438395307848
#  Test: accuracy 90.264 loss 0.2396 f1_score 88.489
# Model Training time:  598.4468553066254 Hour:  0 Minute:  9 Second:  58
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 77
# Epoch: [77][0/106]	Loss 0.1492 (0.1492)	accuracy 95.312 (95.312)	f1_score 92.091 (92.091)
# Epoch: [77][40/106]	Loss 0.1397 (0.1710)	accuracy 93.750 (93.674)	f1_score 90.152 (91.762)
# Epoch: [77][80/106]	Loss 0.2262 (0.1753)	accuracy 92.188 (93.499)	f1_score 94.113 (91.797)
#  Train: accuracy 93.81002917195103  loss 0.1688123197008743  f1 score: 92.13181748130624
#  Test: accuracy 93.510 loss 0.2010 f1_score 91.639
# Model Training time:  605.8991234302521 Hour:  0 Minute:  10 Second:  5
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 78
# Epoch: [78][0/106]	Loss 0.1036 (0.1036)	accuracy 98.438 (98.438)	f1_score 98.887 (98.887)
# Epoch: [78][40/106]	Loss 0.1965 (0.1986)	accuracy 89.062 (92.264)	f1_score 89.030 (90.275)
# Epoch: [78][80/106]	Loss 0.2510 (0.1971)	accuracy 89.062 (92.226)	f1_score 85.692 (90.509)
#  Train: accuracy 92.82545305551753  loss 0.18822309974167675  f1 score: 90.90328855786872
#  Test: accuracy 87.139 loss 0.3763 f1_score 83.961
# Model Training time:  613.4212870597839 Hour:  0 Minute:  10 Second:  13
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 79
# Epoch: [79][0/106]	Loss 0.1837 (0.1837)	accuracy 92.188 (92.188)	f1_score 93.203 (93.203)
# Epoch: [79][40/106]	Loss 0.2549 (0.1713)	accuracy 90.625 (93.445)	f1_score 83.306 (91.549)
# Epoch: [79][80/106]	Loss 0.1020 (0.1707)	accuracy 98.438 (93.596)	f1_score 97.576 (92.093)
#  Train: accuracy 93.51941939653052  loss 0.17080946125180435  f1 score: 92.00706755533767
#  Test: accuracy 92.608 loss 0.1790 f1_score 90.943
# Model Training time:  621.3668971061707 Hour:  0 Minute:  10 Second:  21
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 80
# Epoch: [80][0/106]	Loss 0.1925 (0.1925)	accuracy 95.312 (95.312)	f1_score 94.394 (94.394)
# Epoch: [80][40/106]	Loss 0.1299 (0.1775)	accuracy 96.875 (93.559)	f1_score 95.879 (92.289)
# Epoch: [80][80/106]	Loss 0.1753 (0.1731)	accuracy 90.625 (93.634)	f1_score 90.379 (92.186)
#  Train: accuracy 93.32156766690751  loss 0.1850149573633632  f1 score: 92.10151123444915
#  Test: accuracy 86.538 loss 0.3703 f1_score 83.710
# Model Training time:  628.5094649791718 Hour:  0 Minute:  10 Second:  28
#  Test best accuracy: 94.17067307692308  Test best f1 score: 92.96847374466493
#
# Start of epoch NO: 81
# Epoch: [81][0/106]	Loss 0.1821 (0.1821)	accuracy 93.750 (93.750)	f1_score 93.333 (93.333)
# Epoch: [81][40/106]	Loss 0.1603 (0.1957)	accuracy 92.188 (92.530)	f1_score 93.129 (90.483)
# Epoch: [81][80/106]	Loss 0.2480 (0.1861)	accuracy 87.500 (93.094)	f1_score 85.281 (91.060)
#  Train: accuracy 92.86719069443588  loss 0.19174730725402803  f1 score: 90.73660904785315
#  Test: accuracy 94.712 loss 0.1662 f1_score 93.474
# Saving..
# ...
# Epoch: [273][0/106]	Loss 0.0619 (0.0619)	accuracy 98.438 (98.438)	f1_score 97.884 (97.884)
# Epoch: [273][40/106]	Loss 0.0380 (0.0589)	accuracy 100.000 (98.247)	f1_score 100.000 (97.615)
# Epoch: [273][80/106]	Loss 0.0551 (0.0608)	accuracy 98.438 (98.225)	f1_score 98.586 (97.513)
#  Train: accuracy 98.04820459145353  loss 0.06408660094026969  f1 score: 97.42919866218442
#  Test: accuracy 92.188 loss 0.3749 f1_score 90.384
# Model Training time:  2107.874249458313 Hour:  0 Minute:  35 Second:  7
#  Test best accuracy: 97.89663461538461  Test best f1 score: 97.18832917074607
#
# Start of epoch NO: 274
# Epoch: [274][0/106]	Loss 0.2575 (0.2575)	accuracy 89.062 (89.062)	f1_score 89.621 (89.621)
# Epoch: [274][40/106]	Loss 0.0503 (0.0991)	accuracy 98.438 (97.027)	f1_score 98.586 (95.934)
# Epoch: [274][80/106]	Loss 0.0809 (0.0912)	accuracy 96.875 (97.029)	f1_score 92.727 (95.903)
#  Train: accuracy 96.64132397798653  loss 0.10402637098977925  f1 score: 95.62358180330969
#  Test: accuracy 91.466 loss 0.2394 f1_score 90.031
# Model Training time:  2115.7995612621307 Hour:  0 Minute:  35 Second:  15
#  Test best accuracy: 97.89663461538461  Test best f1 score: 97.18832917074607
#
# Start of epoch NO: 275
# Epoch: [275][0/106]	Loss 0.1841 (0.1841)	accuracy 92.188 (92.188)	f1_score 91.609 (91.609)
# Epoch: [275][40/106]	Loss 0.1109 (0.0742)	accuracy 95.312 (97.561)	f1_score 94.420 (96.852)
# Epoch: [275][80/106]	Loss 0.0699 (0.0676)	accuracy 98.438 (97.878)	f1_score 98.615 (97.245)
#  Train: accuracy 97.53062326284537  loss 0.07343922198923948  f1 score: 96.94322772371459
#  Test: accuracy 92.728 loss 0.2072 f1_score 91.530
# Model Training time:  2122.917718887329 Hour:  0 Minute:  35 Second:  22
#  Test best accuracy: 97.89663461538461  Test best f1 score: 97.18832917074607
#
# Start of epoch NO: 276
# Epoch: [276][0/106]	Loss 0.1220 (0.1220)	accuracy 96.875 (96.875)	f1_score 97.321 (97.321)
# Epoch: [276][40/106]	Loss 0.0667 (0.0789)	accuracy 98.438 (97.752)	f1_score 97.681 (96.858)
# Epoch: [276][80/106]	Loss 0.1482 (0.0804)	accuracy 92.188 (97.627)	f1_score 94.983 (96.707)
#  Train: accuracy 97.74720177347643  loss 0.07944955196677894  f1 score: 96.97130574781806
#  Test: accuracy 88.882 loss 0.4845 f1_score 86.828
# Model Training time:  2131.0122454166412 Hour:  0 Minute:  35 Second:  31
#  Test best accuracy: 97.89663461538461  Test best f1 score: 97.18832917074607
#
# Start of epoch NO: 277
# Epoch: [277][0/106]	Loss 0.0762 (0.0762)	accuracy 98.438 (98.438)	f1_score 93.939 (93.939)
# Epoch: [277][40/106]	Loss 0.0282 (0.0684)	accuracy 100.000 (97.942)	f1_score 100.000 (97.291)
# Epoch: [277][80/106]	Loss 0.1093 (0.0686)	accuracy 96.875 (98.032)	f1_score 93.000 (97.287)
#  Train: accuracy 97.93601799997526  loss 0.07030126149088936  f1 score: 97.15232460157365
#  Test: accuracy 93.810 loss 0.1814 f1_score 92.814
# Model Training time:  2138.2808651924133 Hour:  0 Minute:  35 Second:  38
#  Test best accuracy: 97.89663461538461  Test best f1 score: 97.18832917074607
#
# Start of epoch NO: 278
# Epoch: [278][0/106]	Loss 0.1394 (0.1394)	accuracy 96.875 (96.875)	f1_score 96.739 (96.739)
# Epoch: [278][40/106]	Loss 0.1031 (0.0765)	accuracy 96.875 (97.599)	f1_score 98.095 (96.754)
# Epoch: [278][80/106]	Loss 0.0413 (0.0728)	accuracy 100.000 (97.743)	f1_score 100.000 (96.985)
#  Train: accuracy 97.43206405035824  loss 0.0788158632179278  f1 score: 96.69966197915794
#  Test: accuracy 96.394 loss 0.1023 f1_score 95.275
# Model Training time:  2146.162292957306 Hour:  0 Minute:  35 Second:  46
#  Test best accuracy: 97.89663461538461  Test best f1 score: 97.18832917074607
#
# Start of epoch NO: 279
# Epoch: [279][0/106]	Loss 0.0823 (0.0823)	accuracy 93.750 (93.750)	f1_score 91.677 (91.677)
# Epoch: [279][40/106]	Loss 0.3763 (0.0903)	accuracy 82.812 (96.913)	f1_score 79.242 (95.990)
# Epoch: [279][80/106]	Loss 0.0837 (0.0935)	accuracy 96.875 (96.971)	f1_score 96.111 (96.091)
#  Train: accuracy 97.20794273862  loss 0.08271306182401049  f1 score: 96.4393269924814
#  Test: accuracy 96.514 loss 0.1082 f1_score 95.825
# Model Training time:  2153.99191737175 Hour:  0 Minute:  35 Second:  53
#  Test best accuracy: 97.89663461538461  Test best f1 score: 97.18832917074607
#
# Start of epoch NO: 280
# Epoch: [280][0/106]	Loss 0.0753 (0.0753)	accuracy 96.875 (96.875)	f1_score 97.198 (97.198)
# Epoch: [280][40/106]	Loss 0.0098 (0.0668)	accuracy 100.000 (97.828)	f1_score 100.000 (97.076)
# Epoch: [280][80/106]	Loss 0.0505 (0.0728)	accuracy 98.438 (97.589)	f1_score 97.732 (96.562)
#  Train: accuracy 97.59019874672008  loss 0.07156169578110891  f1 score: 96.60325128667334
#  Test: accuracy 95.733 loss 0.1221 f1_score 94.624
# Model Training time:  2162.2121353149414 Hour:  0 Minute:  36 Second:  2
#  Test best accuracy: 97.89663461538461  Test best f1 score: 97.18832917074607
#
# Start of epoch NO: 281
# Epoch: [281][0/106]	Loss 0.0549 (0.0549)	accuracy 96.875 (96.875)	f1_score 96.087 (96.087)
# Epoch: [281][40/106]	Loss 0.0791 (0.0705)	accuracy 96.875 (97.904)	f1_score 97.348 (97.253)
# Epoch: [281][80/106]	Loss 0.0402 (0.0729)	accuracy 100.000 (97.647)	f1_score 100.000 (96.889)
#  Train: accuracy 97.81268555515086  loss 0.07151634659062313  f1 score: 96.98738326397044
#  Test: accuracy 89.964 loss 0.3265 f1_score 88.947
# Model Training time:  2170.1944873332977 Hour:  0 Minute:  36 Second:  10
#  Test best accuracy: 97.89663461538461  Test best f1 score: 97.18832917074607
#
# Start of epoch NO: 282
# Epoch: [282][0/106]	Loss 0.0351 (0.0351)	accuracy 100.000 (100.000)	f1_score 100.000 (100.000)
# Epoch: [282][40/106]	Loss 0.0761 (0.0748)	accuracy 96.875 (97.790)	f1_score 88.986 (96.258)
# Epoch: [282][80/106]	Loss 0.0399 (0.0688)	accuracy 100.000 (98.206)	f1_score 100.000 (97.215)
#  Train: accuracy 98.01168218540477  loss 0.07100926858139171  f1 score: 97.05297774152857
#  Test: accuracy 96.575 loss 0.1083 f1_score 95.418
# Model Training time:  2177.358838558197 Hour:  0 Minute:  36 Second:  17
#  Test best accuracy: 97.89663461538461  Test best f1 score: 97.18832917074607
#
# Start of epoch NO: 283
# Epoch: [283][0/106]	Loss 0.0387 (0.0387)	accuracy 100.000 (100.000)	f1_score 100.000 (100.000)
# Epoch: [283][40/106]	Loss 0.0392 (0.0680)	accuracy 98.438 (97.904)	f1_score 95.041 (96.948)
# Epoch: [283][80/106]	Loss 0.0106 (0.0681)	accuracy 100.000 (98.052)	f1_score 100.000 (97.285)
#  Train: accuracy 98.01833005266265  loss 0.06665368999525885  f1 score: 97.10057639057
#  Test: accuracy 98.317 loss 0.0735 f1_score 97.880
# Saving..
# Model Training time:  2185.4118509292603 Hour:  0 Minute:  36 Second:  25
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 284
# Epoch: [284][0/106]	Loss 0.0259 (0.0259)	accuracy 100.000 (100.000)	f1_score 100.000 (100.000)
# Epoch: [284][40/106]	Loss 0.1062 (0.0713)	accuracy 96.875 (97.942)	f1_score 97.619 (97.016)
# Epoch: [284][80/106]	Loss 0.0340 (0.0660)	accuracy 100.000 (98.245)	f1_score 100.000 (97.460)
#  Train: accuracy 98.13572576647212  loss 0.06483731732228905  f1 score: 97.26715381546883
#  Test: accuracy 87.260 loss 0.4797 f1_score 84.439
# Model Training time:  2192.9391674995422 Hour:  0 Minute:  36 Second:  32
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 285
# Epoch: [285][0/106]	Loss 0.0632 (0.0632)	accuracy 100.000 (100.000)	f1_score 100.000 (100.000)
# Epoch: [285][40/106]	Loss 0.0495 (0.0657)	accuracy 100.000 (97.828)	f1_score 100.000 (96.744)
# Epoch: [285][80/106]	Loss 0.0628 (0.0674)	accuracy 100.000 (97.859)	f1_score 100.000 (97.186)
#  Train: accuracy 97.91180341444912  loss 0.06817406549385605  f1 score: 97.00258307478447
#  Test: accuracy 97.476 loss 0.0903 f1_score 97.106
# Model Training time:  2200.4795405864716 Hour:  0 Minute:  36 Second:  40
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 286
# Epoch: [286][0/106]	Loss 0.0397 (0.0397)	accuracy 98.438 (98.438)	f1_score 97.835 (97.835)
# Epoch: [286][40/106]	Loss 0.1515 (0.0980)	accuracy 95.312 (96.837)	f1_score 96.818 (95.481)
# Epoch: [286][80/106]	Loss 0.0581 (0.0898)	accuracy 98.438 (97.126)	f1_score 98.586 (96.055)
#  Train: accuracy 97.1170389557295  loss 0.08793460941057248  f1 score: 95.79587225361321
#  Test: accuracy 95.793 loss 0.1048 f1_score 94.745
# Model Training time:  2208.4187960624695 Hour:  0 Minute:  36 Second:  48
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 287
# Epoch: [287][0/106]	Loss 0.0527 (0.0527)	accuracy 98.438 (98.438)	f1_score 98.678 (98.678)
# Epoch: [287][40/106]	Loss 0.0161 (0.0606)	accuracy 100.000 (98.438)	f1_score 100.000 (97.846)
# Epoch: [287][80/106]	Loss 0.1747 (0.0730)	accuracy 92.188 (97.820)	f1_score 92.653 (97.100)
#  Train: accuracy 98.18856619803321  loss 0.064357710275249  f1 score: 97.59264750888724
#  Test: accuracy 97.236 loss 0.0846 f1_score 96.687
# Model Training time:  2215.5583522319794 Hour:  0 Minute:  36 Second:  55
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 288
# Epoch: [288][0/106]	Loss 0.2436 (0.2436)	accuracy 92.188 (92.188)	f1_score 93.439 (93.439)
# Epoch: [288][40/106]	Loss 0.1501 (0.0761)	accuracy 95.312 (97.675)	f1_score 95.321 (96.870)
# Epoch: [288][80/106]	Loss 0.1488 (0.0778)	accuracy 93.750 (97.627)	f1_score 90.373 (96.956)
#  Train: accuracy 97.62216663065817  loss 0.07700600084408689  f1 score: 96.99453662210287
#  Test: accuracy 87.740 loss 0.3552 f1_score 85.156
# Model Training time:  2223.485910177231 Hour:  0 Minute:  37 Second:  3
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 289
# Epoch: [289][0/106]	Loss 0.0451 (0.0451)	accuracy 98.438 (98.438)	f1_score 98.509 (98.509)
# Epoch: [289][40/106]	Loss 0.0135 (0.0623)	accuracy 100.000 (98.285)	f1_score 100.000 (97.853)
# Epoch: [289][80/106]	Loss 0.1838 (0.0652)	accuracy 92.188 (98.071)	f1_score 91.616 (97.442)
#  Train: accuracy 98.21271309006768  loss 0.060982313289487486  f1 score: 97.63834652421849
#  Test: accuracy 90.505 loss 0.4200 f1_score 89.146
# Model Training time:  2230.517340898514 Hour:  0 Minute:  37 Second:  10
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 290
# Epoch: [290][0/106]	Loss 0.0770 (0.0770)	accuracy 96.875 (96.875)	f1_score 93.182 (93.182)
# Epoch: [290][40/106]	Loss 0.1810 (0.0811)	accuracy 92.188 (97.218)	f1_score 90.778 (96.352)
# Epoch: [290][80/106]	Loss 0.0272 (0.0764)	accuracy 98.438 (97.589)	f1_score 98.647 (96.713)
#  Train: accuracy 97.19565666274751  loss 0.0812043627888132  f1 score: 96.2110664906391
#  Test: accuracy 89.603 loss 0.3114 f1_score 87.814
# Model Training time:  2238.428600549698 Hour:  0 Minute:  37 Second:  18
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 291
# Epoch: [291][0/106]	Loss 0.0620 (0.0620)	accuracy 98.438 (98.438)	f1_score 98.182 (98.182)
# Epoch: [291][40/106]	Loss 0.0799 (0.0676)	accuracy 96.875 (98.018)	f1_score 96.429 (97.360)
# Epoch: [291][80/106]	Loss 0.0558 (0.0670)	accuracy 98.438 (97.917)	f1_score 98.155 (97.102)
#  Train: accuracy 97.95476498379696  loss 0.06787003607029585  f1 score: 97.11924361123171
#  Test: accuracy 95.132 loss 0.1527 f1_score 94.026
# Model Training time:  2245.8829429149628 Hour:  0 Minute:  37 Second:  25
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 292
# Epoch: [292][0/106]	Loss 0.1672 (0.1672)	accuracy 90.625 (90.625)	f1_score 92.621 (92.621)
# Epoch: [292][40/106]	Loss 0.0432 (0.0861)	accuracy 100.000 (97.332)	f1_score 100.000 (96.008)
# Epoch: [292][80/106]	Loss 0.0221 (0.0709)	accuracy 100.000 (97.994)	f1_score 100.000 (97.034)
#  Train: accuracy 97.34936499518251  loss 0.08259362574805174  f1 score: 96.26506667978833
#  Test: accuracy 88.942 loss 0.3737 f1_score 87.017
# Model Training time:  2253.475112438202 Hour:  0 Minute:  37 Second:  33
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 293
# Epoch: [293][0/106]	Loss 0.0450 (0.0450)	accuracy 98.438 (98.438)	f1_score 94.709 (94.709)
# Epoch: [293][40/106]	Loss 0.0415 (0.0645)	accuracy 100.000 (97.980)	f1_score 100.000 (97.227)
# Epoch: [293][80/106]	Loss 0.0312 (0.0638)	accuracy 100.000 (98.090)	f1_score 100.000 (97.323)
#  Train: accuracy 98.00303029771193  loss 0.06277619253239601  f1 score: 97.05533184995564
#  Test: accuracy 98.197 loss 0.0649 f1_score 97.600
# Model Training time:  2261.365177631378 Hour:  0 Minute:  37 Second:  41
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 294
# Epoch: [294][0/106]	Loss 0.0821 (0.0821)	accuracy 96.875 (96.875)	f1_score 97.605 (97.605)
# Epoch: [294][40/106]	Loss 0.1354 (0.0814)	accuracy 95.312 (97.599)	f1_score 93.810 (96.886)
# Epoch: [294][80/106]	Loss 0.0864 (0.0816)	accuracy 96.875 (97.415)	f1_score 97.186 (96.584)
#  Train: accuracy 97.4150146761164  loss 0.08309629453669762  f1 score: 96.94639562261669
#  Test: accuracy 97.115 loss 0.0780 f1_score 96.345
# Model Training time:  2268.511647462845 Hour:  0 Minute:  37 Second:  48
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 295
# Epoch: [295][0/106]	Loss 0.1044 (0.1044)	accuracy 95.312 (95.312)	f1_score 94.697 (94.697)
# Epoch: [295][40/106]	Loss 0.0163 (0.0687)	accuracy 100.000 (97.942)	f1_score 100.000 (97.388)
# Epoch: [295][80/106]	Loss 0.0634 (0.0738)	accuracy 98.438 (97.743)	f1_score 97.884 (96.988)
#  Train: accuracy 97.79168371566251  loss 0.07255606732659306  f1 score: 97.19347416829483
#  Test: accuracy 96.575 loss 0.0952 f1_score 96.144
# Model Training time:  2276.501980781555 Hour:  0 Minute:  37 Second:  56
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 296
# Epoch: [296][0/106]	Loss 0.0601 (0.0601)	accuracy 98.438 (98.438)	f1_score 98.286 (98.286)
# Epoch: [296][40/106]	Loss 0.0687 (0.0591)	accuracy 98.438 (98.247)	f1_score 98.758 (97.253)
# Epoch: [296][80/106]	Loss 0.0745 (0.0620)	accuracy 95.312 (98.090)	f1_score 96.206 (97.186)
#  Train: accuracy 98.35686865846708  loss 0.05852813674355136  f1 score: 97.46897347595998
#  Test: accuracy 86.478 loss 0.5061 f1_score 83.475
# Model Training time:  2283.572226047516 Hour:  0 Minute:  38 Second:  3
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 297
# Epoch: [297][0/106]	Loss 0.0161 (0.0161)	accuracy 100.000 (100.000)	f1_score 100.000 (100.000)
# Epoch: [297][40/106]	Loss 0.0275 (0.0749)	accuracy 98.438 (97.752)	f1_score 94.783 (96.564)
# Epoch: [297][80/106]	Loss 0.0626 (0.0708)	accuracy 98.438 (97.917)	f1_score 97.930 (97.095)
#  Train: accuracy 97.87027929507035  loss 0.07184718452242843  f1 score: 96.87860407246991
#  Test: accuracy 94.712 loss 0.1403 f1_score 93.116
# Model Training time:  2291.4778106212616 Hour:  0 Minute:  38 Second:  11
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 298
# Epoch: [298][0/106]	Loss 0.0629 (0.0629)	accuracy 96.875 (96.875)	f1_score 96.508 (96.508)
# Epoch: [298][40/106]	Loss 0.0717 (0.0682)	accuracy 96.875 (97.713)	f1_score 92.381 (96.932)
# Epoch: [298][80/106]	Loss 0.0150 (0.0678)	accuracy 100.000 (97.743)	f1_score 100.000 (97.039)
#  Train: accuracy 97.68845525104  loss 0.06897154231702388  f1 score: 97.09478020087047
#  Test: accuracy 96.875 loss 0.0803 f1_score 96.224
# Model Training time:  2299.027006149292 Hour:  0 Minute:  38 Second:  19
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762
#
# Start of epoch NO: 299
# Epoch: [299][0/106]	Loss 0.0640 (0.0640)	accuracy 96.875 (96.875)	f1_score 93.030 (93.030)
# Epoch: [299][40/106]	Loss 0.0826 (0.0619)	accuracy 95.312 (98.095)	f1_score 96.222 (97.696)
# Epoch: [299][80/106]	Loss 0.1465 (0.0658)	accuracy 95.312 (98.090)	f1_score 95.108 (97.625)
#  Train: accuracy 97.96467524984276  loss 0.0663344107227992  f1 score: 97.34920292417445
#  Test: accuracy 97.536 loss 0.0827 f1_score 97.219
# Model Training time:  2307.8651270866394 Hour:  0 Minute:  38 Second:  27
#  Test best accuracy: 98.3173076923077  Test best f1 score: 97.87974868578762

# %%
len(train_accuracies) , len(train_losses),len(train_f1_scores)
# Out:
# (300, 300, 300)

# %%
len(epoch_train_accuracies) , len(epoch_train_losses),len(epoch_train_f1_scores)
# Out:
# (0, 0, 0)

# %%
len(test_accuracies) , len(test_losses),len(test_f1_scores)
# Out:
# (300, 300, 300)

# %%
test_avg_accuracy = sum(test_accuracies)/len(test_accuracies)
test_avg_loss=sum(test_losses)/len(test_losses)
test_avg_f1_score = sum(test_f1_scores)/len(test_f1_scores)

print('Test_Avg_Accuracy =',float("{:.2f}".format(test_avg_accuracy)))
print('Test_Avg_Loss =',float("{:.2f}".format(test_avg_loss)))
print('Test_Avg_F1_score =',float("{:.2f}".format(test_avg_f1_score)))
# Out:
# Test_Avg_Accuracy = 88.91
# Test_Avg_Loss = 0.36
# Test_Avg_F1_score = 86.76

# %%
train_avg_accuracy = sum(train_accuracies)/len(train_accuracies)
train_avg_loss=sum(train_losses)/len(train_losses)
train_avg_f1_score = sum(train_f1_scores)/len(train_f1_scores)

print('Train_Avg_Accuracy =',float("{:.2f}".format(train_avg_accuracy)))
print('Train_Avg_Loss =',float("{:.2f}".format(train_avg_loss)))
print('Train_Avg_F1_score =',float("{:.2f}".format(train_avg_f1_score)))
# Out:
# Train_Avg_Accuracy = 93.51
# Train_Avg_Loss = 0.18
# Train_Avg_F1_score = 91.93

# %%
plt.figure(figsize=(15,5))
plt.ylabel('Score')
plt.xlabel('Epochs')
plt.plot(test_accuracies, label = "Test Accuracy")
plt.plot(test_f1_scores, label = "Test F1_Score")
plt.legend()

# %%
plt.figure(figsize=(15,5))
plt.ylabel('Score')
plt.xlabel('Epochs')
plt.plot(train_accuracies, label = "Train Accuracy")
plt.plot(train_f1_scores, label = "Train F1_Score")
plt.legend()

# %%
plt.figure(figsize=(15,5))
plt.ylabel('Score')
plt.xlabel('Epochs')
plt.plot(test_accuracies, label = "Test Accuracy")
plt.plot(train_accuracies, label = "Train Accuracy")
plt.legend()

# %%
plt.figure(figsize=(15,5))
plt.ylabel('Score')
plt.xlabel('Epochs')
plt.plot(test_f1_scores, label = "Test F1_Score")
plt.plot(train_f1_scores, label = "Train F1_Score")
plt.legend()

# %%
plt.figure(figsize=(15,5))
plt.ylabel('Score')
plt.xlabel('Epochs')
plt.plot(train_losses, label = "Train loss")
plt.plot(test_losses, label = "Test loss")
plt.legend()

# %%
plt.figure(figsize=(15,5))
plt.ylabel('Training Progress')
plt.xlabel('Epochs')
plt.plot(train_accuracies, label = "Train Accuracy")
plt.plot(train_losses, label = "Train loss")
plt.plot(test_accuracies, label = "Test Accuracy")
plt.plot(test_losses, label = "Test loss")
plt.legend()

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pred = []
y_true = []

# iterate over test data
for inputs, labels in test_loader:
        output = model(inputs) # Feed Network

        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output) # Save Prediction

        labels = labels.data.cpu().numpy()
        y_true.extend(labels) # Save Truth

# constant for classes
classes = ( 'Normal_walking','Moderate_walking','vigorous_walking',
            'Standing','Normal_Upstairs','Moderate_Upstairs','vigorous_Upstairs',
            'Normal_downstairs','Moderate_downstairs','Vigorous_downstairs',
            'Drinking','Eating','Itching','Lying',
            'Using_toilet','Jogging','Cycling','irrelevant','Driving','stting_new','Dips','Hanging_Leg','Push_Up')

# Build confusion matrix
cf_matrix = confusion_matrix(y_true, y_pred)
df_cm = pd.DataFrame(cf_matrix / np.sum(cf_matrix, axis=1)[:, None], index = [i for i in classes],
                     columns = [i for i in classes])
plt.figure(figsize = (15,15))
sns.heatmap(df_cm, annot=True)
plt.ylabel('True Labels')
plt.xlabel('Predicted Labels')
plt.savefig('output.png')

# %%
#PATH =

# %%
#torch.save(model, PATH)

# %%
#modelB= torch.load("/content/checkpoint/best_model_ckpt.t7")
#modelB.eval()
